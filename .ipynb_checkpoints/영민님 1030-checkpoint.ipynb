# %% [markdown]
# - [T-Academy X KaKr] 성인 인구조사 소득 예측 대회

# %% [markdown]
# 대회는 총 3개의 파일 제공합니다.
#
# - train.csv : training set. 훈련용 데이터
# - test.csv : test set, 제출용 데이터
# - submission_example.csv : 제출파일 예시
# - 데이터 세부 설명
# - train/test는 14개의 columns으로 구성되어 있고, train은 예측해야 하는 target 값 feature까지 1개가 추가로 있습니다. 각 데이터는 다음을 의미합니다.
#
# - id
# - age : 나이
# - workclass : 고용 형태
# - fnlwgt : 사람 대표성을 나타내는 가중치 (final weight의 약자) 해당 대상이 전체를 얼마나 대표하고 있는지에 대한 가중치
# - education : 교육 수준
# - education_num : 교육 수준 수치
# - marital_status: 결혼 상태
# - occupation : 업종
# - relationship : 가족 관계
# - race : 인종
# - sex : 성별
# - capital_gain : 양도 소득
# - capital_loss : 양도 손실
# - hours_per_week : 주당 근무 시간
# - native_country : 국적
# - income : 수익 (예측해야 하는 값)
# - >50K : 1
# - <=50K : 0

# %%
CPS (Current Population Survey) 파일의 가중치는 미국의 민간인 비 기관 인구에 대한 독립적 인 추정치로 제어됩니다. 

이것은 인구 조사국의 인구과에서 매월 준비합니다. 3 세트의 컨트롤을 사용합니다. 

이것들은:

각 주에 대한 16 세 이상의 인구에 대한 단일 세포 추정치.

연령 및 성별에 따른 히스패닉계에 대한 통제.

인종, 연령 및 성별에 따른 통제.


가중치 프로그램에서 세 세트의 컨트롤을 모두 사용하고 6 번 "레이크"하여 결국 사용했던 모든 컨트롤로 돌아갑니다.

용어 추정치는 인구의 특정 사회 경제적 특성에 대한 "가중치 계산"을 생성하여 CPS에서 파생 된 인구 총계를 나타냅니다. 

비슷한 인구 통계 학적 특성을 가진 사람들은 비슷한 가중치를 가져야합니다. 이 진술에 대해 기억해야 할 중요한주의 사항이 있습니다. 

즉, CPS 샘플은 실제로 51 개 상태 샘플의 모음이며, 각각 고유 한 선택 확률을 가지고 있기 때문에 문은 상태 내에서만 적용됩니다.

# %%
# 데이터 분석 라이브러리
import numpy as np
import pandas as pd

# 시각화 라이브러리
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install lightgbm

# %%
# 데이터 분석 라이브러리
import numpy as np
import pandas as pd

# 시각화 라이브러리
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from plotnine import *

# 모델링 라이브러리
from category_encoders.ordinal import OrdinalEncoder
from sklearn.model_selection import KFold
from lightgbm import LGBMClassifier

# 기타 라이브러리
import random
import gc
import os

# %%
pwd
# Out:
# '/Users/pym'

# %%
cd data/kakr-4th-competition
# Out:
# /Users/pym/data/kakr-4th-competition

# %%
cd kakr-4th-competition
# Out:
# [Errno 2] No such file or directory: 'kakr-4th-competition'
# /Users/pym/data/kakr-4th-competition

# %%
ll
# Out:
# total 7592
# -rw-rw-r--@ 1 pym  staff    44488 Oct 13 11:00 sample_submission.csv
# -rw-r--r--  1 pym  staff    44488 Oct 27 16:35 submission.csv
# -rw-r--r--  1 pym  staff    44488 Oct 27 16:50 submission_1.csv
# -rw-r--r--  1 pym  staff    44488 Oct 27 16:50 submission_2.csv
# -rw-r--r--  1 pym  staff    44488 Oct 27 19:35 submission_3.csv
# -rw-rw-r--@ 1 pym  staff   699385 Oct 13 11:00 test.csv
# -rw-rw-r--@ 1 pym  staff  2958474 Oct 13 11:00 train.csv

# %% [markdown]
# # 데이터불러오기

# %%
test = pd.read_csv("./test.csv")

train = pd.read_csv("./train.csv")

sample_submission = pd.read_csv("./sample_submission.csv")

# %%
train
# Out:
#           id  age         workclass  fnlwgt     education  education_num  \
# 0          0   40           Private  168538       HS-grad              9
# 1          1   17           Private  101626           9th              5
# 2          2   18           Private  353358  Some-college             10
# 3          3   21           Private  151158  Some-college             10
# 4          4   24           Private  122234  Some-college             10
# ...      ...  ...               ...     ...           ...            ...
# 26044  26044   57           Private  250201          11th              7
# 26045  26045   23           Private  238092     Bachelors             13
# 26046  26046   78                 ?  165694       Masters             14
# 26047  26047   26  Self-emp-not-inc  151626       HS-grad              9
# 26048  26048   20                 ?   99891  Some-college             10
#
#            marital_status         occupation   relationship   race     sex  \
# 0      Married-civ-spouse              Sales        Husband  White    Male
# 1           Never-married  Machine-op-inspct      Own-child  White    Male
# 2           Never-married      Other-service      Own-child  White    Male
# 3           Never-married     Prof-specialty      Own-child  White  Female
# 4           Never-married       Adm-clerical  Not-in-family  Black  Female
# ...                   ...                ...            ...    ...     ...
# 26044  Married-civ-spouse      Other-service        Husband  White    Male
# 26045       Never-married     Prof-specialty      Own-child  White    Male
# 26046             Widowed                  ?  Not-in-family  White  Female
# 26047       Never-married     Prof-specialty      Own-child  Black  Female
# 26048       Never-married                  ?      Own-child  White  Female
#
#        capital_gain  capital_loss  hours_per_week native_country income
# 0                 0             0              60  United-States   >50K
# 1                 0             0              20  United-States  <=50K
# 2                 0             0              16  United-States  <=50K
# 3                 0             0              25  United-States  <=50K
# 4                 0             0              20              ?  <=50K
# ...             ...           ...             ...            ...    ...
# 26044             0             0              52  United-States  <=50K
# 26045             0             0              40  United-States  <=50K
# 26046             0             0              15  United-States  <=50K
# 26047             0             0              40  United-States  <=50K
# 26048             0             0              30  United-States  <=50K
#
# [26049 rows x 16 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26049 entries, 0 to 26048
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              26049 non-null  int64
#  1   age             26049 non-null  int64
#  2   workclass       26049 non-null  object
#  3   fnlwgt          26049 non-null  int64
#  4   education       26049 non-null  object
#  5   education_num   26049 non-null  int64
#  6   marital_status  26049 non-null  object
#  7   occupation      26049 non-null  object
#  8   relationship    26049 non-null  object
#  9   race            26049 non-null  object
#  10  sex             26049 non-null  object
#  11  capital_gain    26049 non-null  int64
#  12  capital_loss    26049 non-null  int64
#  13  hours_per_week  26049 non-null  int64
#  14  native_country  26049 non-null  object
#  15  income          26049 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 3.2+ MB

# %%
train.describe()
# Out:
#                  id           age        fnlwgt  education_num  capital_gain  \
# count  26049.000000  26049.000000  2.604900e+04   26049.000000   26049.00000
# mean   13024.000000     38.569235  1.903045e+05      10.088372    1087.68970
# std     7519.842917     13.671489  1.059663e+05       2.567610    7388.85469
# min        0.000000     17.000000  1.376900e+04       1.000000       0.00000
# 25%     6512.000000     28.000000  1.181080e+05       9.000000       0.00000
# 50%    13024.000000     37.000000  1.788660e+05      10.000000       0.00000
# 75%    19536.000000     48.000000  2.377350e+05      12.000000       0.00000
# max    26048.000000     90.000000  1.484705e+06      16.000000   99999.00000
#
#        capital_loss  hours_per_week
# count  26049.000000    26049.000000
# mean      87.732734       40.443126
# std      403.230205       12.361850
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
train.describe(include='O')
# Out:
#        workclass education      marital_status      occupation relationship  \
# count      26049     26049               26049           26049        26049
# unique         9        16                   7              15            6
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       18123      8433               11970            3304        10541
#
#          race    sex native_country income
# count   26049  26049          26049  26049
# unique      5      2             41      2
# top     White   Male  United-States  <=50K
# freq    22315  17482          23371  19744

# %%
train[train['education_num'] == 4]['education'].head(6)
# Out:
# 43     7th-8th
# 81     7th-8th
# 95     7th-8th
# 122    7th-8th
# 136    7th-8th
# 261    7th-8th
# Name: education, dtype: object

# %%
#범주형 데이터의 항목값들
for col in train.columns:
    if train[col].dtype == 'object':
        categories = train[col].unique()
        print(f'[{col}] ({len(categories)})')
        print('\n'.join(categories))
        print()
# Out:
# [workclass] (9)
# Private
# State-gov
# ?
# Self-emp-not-inc
# Local-gov
# Federal-gov
# Self-emp-inc
# Without-pay
# Never-worked
#
# [education] (16)
# HS-grad
# 9th
# Some-college
# Bachelors
# 11th
# 1st-4th
# 5th-6th
# Assoc-acdm
# 10th
# Prof-school
# 7th-8th
# Masters
# Assoc-voc
# Doctorate
# 12th
# Preschool
#
# [marital_status] (7)
# Married-civ-spouse
# Never-married
# Separated
# Married-spouse-absent
# Divorced
# Widowed
# Married-AF-spouse
#
# [occupation] (15)
# Sales
# Machine-op-inspct
# Other-service
# Prof-specialty
# Adm-clerical
# Craft-repair
# ?
# Handlers-cleaners
# Farming-fishing
# Exec-managerial
# Transport-moving
# Protective-serv
# Tech-support
# Priv-house-serv
# Armed-Forces
#
# [relationship] (6)
# Husband
# Own-child
# Not-in-family
# Unmarried
# Wife
# Other-relative
#
# [race] (5)
# White
# Black
# Asian-Pac-Islander
# Other
# Amer-Indian-Eskimo
#
# [sex] (2)
# Male
# Female
#
# [native_country] (41)
# United-States
# ?
# Mexico
# Poland
# Philippines
# Puerto-Rico
# Vietnam
# Germany
# Cuba
# France
# Ireland
# El-Salvador
# Guatemala
# Haiti
# Trinadad&Tobago
# Jamaica
# Canada
# Taiwan
# South
# Columbia
# Peru
# Japan
# Dominican-Republic
# China
# England
# Iran
# India
# Nicaragua
# Italy
# Honduras
# Thailand
# Ecuador
# Portugal
# Hungary
# Greece
# Hong
# Outlying-US(Guam-USVI-etc)
# Cambodia
# Scotland
# Yugoslavia
# Laos
#
# [income] (2)
# >50K
# <=50K

# %%
#범주형 데이터의 유니크 값의 개수
for col in train.columns:
    if train[col].dtype == 'object':
        categories = train[col].unique()
        print(f'[{col}] ({len(categories)})')
# Out:
# [workclass] (9)
# [education] (16)
# [marital_status] (7)
# [occupation] (15)
# [relationship] (6)
# [race] (5)
# [sex] (2)
# [native_country] (41)
# [income] (2)

# %% [markdown]
# # EDA - 1

# %% [markdown]
# ## object column 단순시각화

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26049 entries, 0 to 26048
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              26049 non-null  int64
#  1   age             26049 non-null  int64
#  2   workclass       26049 non-null  object
#  3   fnlwgt          26049 non-null  int64
#  4   education       26049 non-null  object
#  5   education_num   26049 non-null  int64
#  6   marital_status  26049 non-null  object
#  7   occupation      26049 non-null  object
#  8   relationship    26049 non-null  object
#  9   race            26049 non-null  object
#  10  sex             26049 non-null  object
#  11  capital_gain    26049 non-null  int64
#  12  capital_loss    26049 non-null  int64
#  13  hours_per_week  26049 non-null  int64
#  14  native_country  26049 non-null  object
#  15  income          26049 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 3.2+ MB

# %%
col_lst = train.columns.tolist()

# %%
col_lst
# Out:
# ['id',
#  'age',
#  'workclass',
#  'fnlwgt',
#  'education',
#  'education_num',
#  'marital_status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capital_gain',
#  'capital_loss',
#  'hours_per_week',
#  'native_country',
#  'income']

# %%
def view_count_barplot(i):
    df = pd.DataFrame(train[i].value_counts())
    df = df.reset_index()
    df.columns= [i, 'count']
    df = df.sort_values(by = ['count'], ascending = False)

    f, ax = plt.subplots(figsize=(15, 8))
    sns.barplot(
        data= df,
        x= i,
        y= "count"
    )
    plt.xticks(rotation = - 90 )
    plt.show()

# %% [markdown]
# ### 인구컬럼

# %% [markdown]
# ### 성별컬럼

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 6))
sns.countplot(x='sex', data=train)
plt.show()
#남자가 여자보다 훨씬 많다.

# %% [markdown]
# ### 나이컬럼

# %%
age_df = pd.DataFrame(train.age.value_counts())
age_df = age_df.reset_index()
age_df.columns= ['age', 'count']

age_df = age_df.sort_values(by = ['age'])

f, ax = plt.subplots(figsize=(15, 8))
sns.barplot(
    data= age_df,
    x= "age",
    y= "count"
)
plt.xticks(rotation = - 90 )
plt.show()
#인구분포정도

# %% [markdown]
# ### 직업컬럼

# %%
workclass_df = pd.DataFrame(train.workclass.value_counts())
workclass_df = workclass_df.reset_index()
workclass_df.columns= ['workclass', 'count']
workclass_df = workclass_df.sort_values(by = ['count'], ascending = False)

f, ax = plt.subplots(figsize=(15, 8))
sns.barplot(
    data= workclass_df,
    x= "workclass",
    y= "count"
)
plt.xticks(rotation = - 90 )
plt.show()
#인구분포정도

# %% [markdown]
# ### 교육수준

# %%
education_df = pd.DataFrame(train.education.value_counts())
education_df = education_df.reset_index()
education_df.columns= ['education', 'count']
education_df = education_df.sort_values(by = ['count'], ascending = False)

f, ax = plt.subplots(figsize=(15, 8))
sns.barplot(
    data= education_df,
    x= "education",
    y= "count"
)
plt.xticks(rotation = - 90 )
plt.show()

# %% [markdown]
# ### 결혼상태

# %%
marital_status_df = pd.DataFrame(train.marital_status.value_counts())
marital_status_df = marital_status_df.reset_index()
marital_status_df.columns= ['marital_status', 'count']
marital_status_df = marital_status_df.sort_values(by = ['count'], ascending = False)

f, ax = plt.subplots(figsize=(15, 8))
sns.barplot(
    data= marital_status_df,
    x= "marital_status",
    y= "count"
)
plt.xticks(rotation = - 90 )
plt.show()

# %%
view_count_barplot(col_lst[7]) #occupation

# %% [markdown]
# ### 업종컬럼

# %%
view_count_barplot(col_lst[8]) #relationship

# %% [markdown]
# ### 인종컬럼

# %%
view_count_barplot(col_lst[9]) #race

# %% [markdown]
# ### 국적컬럼

# %%
view_count_barplot(col_lst[14]) #native_country

# %% [markdown]
# ### 수입컬럼

# %%
view_count_barplot(col_lst[15]) #income

# %%
train.income.value_counts()
# Out:
# <=50K    19744
# >50K      6305
# Name: income, dtype: int64

# %%
19744/6305
# Out:
# 3.131482950039651

# %% [markdown]
# ## 수치형 column 단순시각화

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26049 entries, 0 to 26048
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              26049 non-null  int64
#  1   age             26049 non-null  int64
#  2   workclass       26049 non-null  object
#  3   fnlwgt          26049 non-null  int64
#  4   education       26049 non-null  object
#  5   education_num   26049 non-null  int64
#  6   marital_status  26049 non-null  object
#  7   occupation      26049 non-null  object
#  8   relationship    26049 non-null  object
#  9   race            26049 non-null  object
#  10  sex             26049 non-null  object
#  11  capital_gain    26049 non-null  int64
#  12  capital_loss    26049 non-null  int64
#  13  hours_per_week  26049 non-null  int64
#  14  native_country  26049 non-null  object
#  15  income          26049 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 3.2+ MB

# %%
def col_num_describe(x):
    df = train[[x, 'income']]
    dn = df[df.income == '<=50K'].reset_index(drop = True)
    up = df[df.income == '>50K'].reset_index(drop = True)
    print("<=50K", dn.describe())
    print(">50K", up.describe())

# %% [markdown]
# ### fnlwgt(대표성)컬럼

# %%
col_num_describe('fnlwgt')
# Out:
# <=50K              fnlwgt
# count  1.974400e+04
# mean   1.907536e+05
# std    1.070992e+05
# min    1.376900e+04
# 25%    1.176825e+05
# 50%    1.799510e+05
# 75%    2.394210e+05
# max    1.484705e+06
# >50K              fnlwgt
# count  6.305000e+03
# mean   1.888982e+05
# std    1.023330e+05
# min    1.487800e+04
# 25%    1.199390e+05
# 50%    1.767560e+05
# 75%    2.313480e+05
# max    1.226583e+06

# %% [markdown]
# ### 교육수준수치(education_num)컬럼

# %%
col_num_describe('education_num')
#임금이 높은 사람이 평균적으로 교육수준이 2가 더 높았다.
# Out:
# <=50K        education_num
# count   19744.000000
# mean        9.602917
# std         2.432380
# min         1.000000
# 25%         9.000000
# 50%         9.000000
# 75%        10.000000
# max        16.000000
# >50K        education_num
# count    6305.000000
# mean       11.608565
# std         2.379452
# min         2.000000
# 25%        10.000000
# 50%        13.000000
# 75%        13.000000
# max        16.000000

# %% [markdown]
# ### 양도소득컬럼(capital_gain )

# %%
col_num_describe("capital_gain") #평균에서 어마어마한 차이를 보인다.
# Out:
# <=50K        capital_gain
# count  19744.000000
# mean     146.998987
# std      938.137147
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max    41310.000000
# >50K        capital_gain
# count   6305.000000
# mean    4033.446630
# std    14538.895521
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max    99999.000000

# %% [markdown]
# ### 양도손실컬럼(capital_loss)

# %%
col_num_describe("capital_loss") #양도소득에 비해서는 낮지만 평균에서 차이를 보인다.
# Out:
# <=50K        capital_loss
# count  19744.000000
# mean      52.975537
# std      309.518137
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max     4356.000000
# >50K        capital_loss
# count   6305.000000
# mean     196.574306
# std      596.801894
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max     3683.000000

# %% [markdown]
# ### 주당근무시간(hours_per_week)컬럼

# %%
col_num_describe("hours_per_week") #평균적으로 근무시간이 많을수록 돈을 더 많이번다.
# Out:
# <=50K        hours_per_week
# count    19744.000000
# mean        38.810423
# std         12.327298
# min          1.000000
# 25%         35.000000
# 50%         40.000000
# 75%         40.000000
# max         99.000000
# >50K        hours_per_week
# count     6305.000000
# mean        45.555908
# std         11.000797
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         50.000000
# max         99.000000

# %% [markdown]
# ## 수입에 따른 두 집단 시각화

# %%
train
# Out:
#           id  age         workclass  fnlwgt     education  education_num  \
# 0          0   40           Private  168538       HS-grad              9
# 1          1   17           Private  101626           9th              5
# 2          2   18           Private  353358  Some-college             10
# 3          3   21           Private  151158  Some-college             10
# 4          4   24           Private  122234  Some-college             10
# ...      ...  ...               ...     ...           ...            ...
# 26044  26044   57           Private  250201          11th              7
# 26045  26045   23           Private  238092     Bachelors             13
# 26046  26046   78                 ?  165694       Masters             14
# 26047  26047   26  Self-emp-not-inc  151626       HS-grad              9
# 26048  26048   20                 ?   99891  Some-college             10
#
#            marital_status         occupation   relationship   race     sex  \
# 0      Married-civ-spouse              Sales        Husband  White    Male
# 1           Never-married  Machine-op-inspct      Own-child  White    Male
# 2           Never-married      Other-service      Own-child  White    Male
# 3           Never-married     Prof-specialty      Own-child  White  Female
# 4           Never-married       Adm-clerical  Not-in-family  Black  Female
# ...                   ...                ...            ...    ...     ...
# 26044  Married-civ-spouse      Other-service        Husband  White    Male
# 26045       Never-married     Prof-specialty      Own-child  White    Male
# 26046             Widowed                  ?  Not-in-family  White  Female
# 26047       Never-married     Prof-specialty      Own-child  Black  Female
# 26048       Never-married                  ?      Own-child  White  Female
#
#        capital_gain  capital_loss  hours_per_week native_country income
# 0                 0             0              60  United-States   >50K
# 1                 0             0              20  United-States  <=50K
# 2                 0             0              16  United-States  <=50K
# 3                 0             0              25  United-States  <=50K
# 4                 0             0              20              ?  <=50K
# ...             ...           ...             ...            ...    ...
# 26044             0             0              52  United-States  <=50K
# 26045             0             0              40  United-States  <=50K
# 26046             0             0              15  United-States  <=50K
# 26047             0             0              40  United-States  <=50K
# 26048             0             0              30  United-States  <=50K
#
# [26049 rows x 16 columns]

# %%
from plotnine import *

# %% [markdown]
# ### 나이에 따른 소득 수준 (Age vs income)

# %%
fig = plt.figure()

# %%
ggplot(train, aes(x="age", fill="income")) + geom_density(alpha=0.7) + ggtitle("The age distribution by income")
# Out:
# <ggplot: (8761444075180)>

# %% [markdown]
# ### Final weight 따른 소득 수준 (fnlwgt vs income)

# %%
fig = plt.figure()
ggplot(train, aes(x="fnlwgt", fill='income')) + geom_density(alpha=0.7) + ggtitle('The final weight distribution by income')
# Out:
# <ggplot: (8761443268732)>

# %% [markdown]
# ### 교육에 따른 소득 수준 (education_num vs income)

# %%
fig = plt.figure()
ggplot(train, aes(x='education_num', fill='income')) + geom_density(alpha=0.7) + ggtitle('The education_num distribution by income')
# Out:
# <ggplot: (8761444084535)>

# %%
sns.boxplot(x='income', y='education_num', data=train, palette="Set2", linewidth=2);

# %% [markdown]
# ### 양도세에 따른 소득 수준 (capital vs income)

# %%
fig = plt.figure()
ggplot(train.loc[train['capital_gain'] > 0], aes(x='capital_gain', fill='income')) + geom_density(alpha=0.7) + ggtitle('The capital loss distribution by income')
# Out:
# <ggplot: (8761445174453)>

# %%
sns.boxplot(x='income', y='capital_gain', data=train.loc[train['capital_gain'] > 0], palette="Set2", linewidth=2);

# %%
fig = plt.figure();
ggplot(train.loc[train['capital_loss'] > 0], aes(x='capital_loss', fill='income')) + geom_density(alpha=0.7) + ggtitle('The capital loss distribution by income')
# Out:
# <ggplot: (8761444878141)>

# %%
sns.boxplot(x='income', y='capital_loss', data=train.loc[train['capital_loss'] > 0], palette="Set2", linewidth=2);

# %% [markdown]
# ### 주당 근무시간에 따른 소득 수준 (hours_per_week vs income

# %%
fig = plt.figure()
ggplot(train, aes(x='hours_per_week', fill='income')) + geom_density(alpha=0.7) + ggtitle('The hours per week distribution by income')
# Out:
# <ggplot: (8761443268753)>

# %%
sns.boxplot(x='income', y='hours_per_week', data=train, palette="Set2", linewidth=2);

# %% [markdown]
# ### workclass_income

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 7))
col = 'workclass'
value_counts = train[col].value_counts()
sns.countplot(x=col, data=train, palette="Set2", edgecolor='black', order = value_counts.index)

# bar 상단에 count 숫자로 입력
for i, v in value_counts.reset_index().iterrows():
    ax.text(i-0.1, v[col]+150 , v[col])

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 7))
value_counts = train[col].value_counts()
sns.countplot(x=col, hue='income', data=train, palette="Set2", edgecolor='black', order = value_counts.index);

# %% [markdown]
# ### education_income

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 7))
col = 'education_num'
value_counts = train[col].value_counts().sort_index()
sns.countplot(x=col, data=train, palette="Set2", edgecolor='black', order = value_counts.index)
plt.xticks(rotation=45)

for i, v in value_counts.reset_index().iterrows():
    ax.text(i-0.1, v[col]+150 , v[col])

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 7))
value_counts = train[col].value_counts().sort_index()
sns.countplot(x=col, hue='income', data=train, palette="Set2", edgecolor='black', order = value_counts.index);

# %% [markdown]
# ### martial_status_income

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 7))
col = 'marital_status'
value_counts = train[col].value_counts()
sns.countplot(x=col, data=train, palette="Set2", edgecolor='black', order = value_counts.index)

for i, v in value_counts.reset_index().iterrows():
    ax.text(i-0.1, v[col]+150 , v[col])

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 7))
value_counts = train[col].value_counts()
sns.countplot(x=col, hue='income', data=train, palette="Set2", edgecolor='black', order = value_counts.index);

# %% [markdown]
# ### occupation_income

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 7))
col = 'occupation'
value_counts = train[col].value_counts()
sns.countplot(x=col, data=train, palette="Set2", edgecolor='black', order = value_counts.index)
plt.xticks(rotation=45)

for i, v in value_counts.reset_index().iterrows():
    ax.text(i-0.12, v[col]+50 , v[col])

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
value_counts = train[col].value_counts()
sns.countplot(y=col, hue='income', data=train, palette="Set2", edgecolor='black', order = value_counts.index);

# %% [markdown]
# ### Relationship_income

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 7))
col = 'relationship'
value_counts = train[col].value_counts()
sns.countplot(x=col, data=train, palette="Set2", edgecolor='black', order = value_counts.index)

for i, v in value_counts.reset_index().iterrows():
    ax.text(i-0.1, v[col]+150 , v[col])

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
value_counts = train[col].value_counts()
sns.countplot(x=col, hue='income', data=train, palette="Set2", edgecolor='black', order = value_counts.index);

# %% [markdown]
# ### race_income

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
col = 'race'
value_counts = train[col].value_counts()
sns.countplot(x=col, data=train, palette="Set2", edgecolor='black', order = value_counts.index)

for i, v in value_counts.reset_index().iterrows():
    ax.text(i-0.1, v[col]+150 , v[col])

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
value_counts = train[col].value_counts()
sns.countplot(x=col, hue='income', data=train, palette="Set2", edgecolor='black', order = value_counts.index);

# %% [markdown]
# ### sex_income

# %%
fig, ax = plt.subplots(1, 1, figsize=(7, 4))
col = 'sex'
value_counts = train[col].value_counts()
sns.countplot(x=col, data=train, palette="Set2", edgecolor='black', order = value_counts.index)

for i, v in value_counts.reset_index().iterrows():
    ax.text(i-0.05, v[col]+150 , v[col])

# %%
fig, ax = plt.subplots(1, 1, figsize=(7, 4))
value_counts = train[col].value_counts()
sns.countplot(x=col, hue='income', data=train, palette="Set2", edgecolor='black', order = value_counts.index);

# %%
fig, ax = plt.subplots(1, 1, figsize=(7, 7))
train_us = train[train['native_country']=='United-States']
col = 'native_country'
sns.countplot(x=col, hue='income', data=train_us, palette="Set2", edgecolor='black');

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 20))
train_other = train[train['native_country']!='United-States']
sns.countplot(y=col, hue='income', data=train_other, palette="Set2", edgecolor='black');

# %% [markdown]
# # EDA -2

# %%
# 데이터 분석 라이브러리
import numpy as np
import pandas as pd

# 시각화 라이브러리
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from plotnine import *

# 모델링 라이브러리
from category_encoders.ordinal import OrdinalEncoder
from sklearn.model_selection import KFold
from lightgbm import LGBMClassifier

# 기타 라이브러리
import random
import gc
import os

# %%
pd.set_option('display.max_rows', 200)
pd.set_option('display.width', 10000)
pd.options.display.float_format = '{:.3f}'.format

# %%
cd data/kakr-4th-competition
# Out:
# [Errno 2] No such file or directory: 'data/kakr-4th-competition'
# /Users/pym/data/kakr-4th-competition

# %%
test = pd.read_csv("./test.csv")

train = pd.read_csv("./train.csv")

sample_submission = pd.read_csv("./sample_submission.csv")

# %%
train
# Out:
#           id  age         workclass  fnlwgt     education  education_num      marital_status         occupation   relationship   race     sex  capital_gain  capital_loss  hours_per_week native_country income
# 0          0   40           Private  168538       HS-grad              9  Married-civ-spouse              Sales        Husband  White    Male             0             0              60  United-States   >50K
# 1          1   17           Private  101626           9th              5       Never-married  Machine-op-inspct      Own-child  White    Male             0             0              20  United-States  <=50K
# 2          2   18           Private  353358  Some-college             10       Never-married      Other-service      Own-child  White    Male             0             0              16  United-States  <=50K
# 3          3   21           Private  151158  Some-college             10       Never-married     Prof-specialty      Own-child  White  Female             0             0              25  United-States  <=50K
# 4          4   24           Private  122234  Some-college             10       Never-married       Adm-clerical  Not-in-family  Black  Female             0             0              20              ?  <=50K
# ...      ...  ...               ...     ...           ...            ...                 ...                ...            ...    ...     ...           ...           ...             ...            ...    ...
# 26044  26044   57           Private  250201          11th              7  Married-civ-spouse      Other-service        Husband  White    Male             0             0              52  United-States  <=50K
# 26045  26045   23           Private  238092     Bachelors             13       Never-married     Prof-specialty      Own-child  White    Male             0             0              40  United-States  <=50K
# 26046  26046   78                 ?  165694       Masters             14             Widowed                  ?  Not-in-family  White  Female             0             0              15  United-States  <=50K
# 26047  26047   26  Self-emp-not-inc  151626       HS-grad              9       Never-married     Prof-specialty      Own-child  Black  Female             0             0              40  United-States  <=50K
# 26048  26048   20                 ?   99891  Some-college             10       Never-married                  ?      Own-child  White  Female             0             0              30  United-States  <=50K
#
# [26049 rows x 16 columns]

# %%
#특정 컬럼에서 특정항목값의 수익이 높은 사람의 수 / 특정컬럼에서 특정항목값 총 사람의 수 => 수입이 높은 사람의 비율
def portion_income(column):
    train[column] = train[column].astype('str')
    col_lst = train[column].unique().tolist()
    df = train[[column,'income']]

    for x in col_lst:
        locals()["high" + '_' + x] = df[(df[column] == x) & (df.income == ">50K")]
        locals()["low" + '_' + x]  = df[(df[column] == x) & (df.income == "<=50K")]
    col_name = []
    col_name_value = []
    for x in col_lst:
        col_name.append(x)
        col_name_value.append(len(locals()["high" + '_' + x]) / (len(locals()["high" + '_' + x]) + len(locals()["low" + '_' + x])))
        #print(x , len(locals()["high" + '_' + x]) / (len(locals()["high" + '_' + x]) + len(locals()["low" + '_' + x])))
    data = pd.DataFrame({"name" : col_name, "value" : col_name_value }).sort_values(by = 'value', ascending = False)
    data.columns = [column, '{}_income_up_portion'.format(column)]
    return data

# %% [markdown]
# ### workclass

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 7))
col = 'workclass'
value_counts = train[col].value_counts()
sns.countplot(x=col, data=train, palette="Set2", edgecolor='black', order = value_counts.index)

# bar 상단에 count 숫자로 입력
for i, v in value_counts.reset_index().iterrows():
    ax.text(i-0.1, v[col]+150 , v[col])

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 7))
value_counts = train[col].value_counts()
sns.countplot(x=col, hue='income', data=train, palette="Set2", edgecolor='black', order = value_counts.index);

# %% [markdown]
# - 고용형태당 고수입의 비율이 어느정도 되는지 살펴보자

# %%
workclass_list = train.workclass.unique().tolist()
workclass_df = train[['workclass','income']]

# %%
for x in workclass_list:
    locals()["high" + '_' + x] = workclass_df[(workclass_df.workclass == x) & (workclass_df.income == ">50K")]
    locals()["low" + '_' + x]  = workclass_df[(workclass_df.workclass == x) & (workclass_df.income == "<=50K")]

# %%
for x in workclass_list:
    print(x , len(locals()["high" + '_' + x]) / (len(locals()["high" + '_' + x]) + len(locals()["low" + '_' + x])))
# Out:
# Private 0.22032776030458534
# State-gov 0.27708533077660596
# ? 0.10186418109187749
# Self-emp-not-inc 0.28423645320197044
# Local-gov 0.2984633569739953
# Federal-gov 0.38169934640522873
# Self-emp-inc 0.5655644241733181
# Without-pay 0.0
# Never-worked 0.0

# %%
workclass_protion = portion_income("workclass")

# %%
workclass_protion
# Out:
#           workclass  workclass_income_up_portion
# 6      Self-emp-inc                        0.566
# 5       Federal-gov                        0.382
# 4         Local-gov                        0.298
# 3  Self-emp-not-inc                        0.284
# 1         State-gov                        0.277
# 0           Private                        0.220
# 2                 ?                        0.102
# 7       Without-pay                        0.000
# 8      Never-worked                        0.000

# %% [markdown]
# 고용형태(workclass)
# - Self-emp-inc(법인있는 자영업) - 56.5%
#     - Refers to people who work for themselves in corporate entities.
#     - 기업에서 스스로 일하는 사람들을 의미합니다.
#
# - Federal-gov(연방 정부) - 38.1%
# - Local-gov(지방 정부) - 29.8%
#
# - Self-emp-not-inc(법인 없는 자영업) - 28.4%
#     - Refers to people who work for themselves in other legal entities.
#     - 다른 법인에서 스스로 일하는 사람들을 나타냅니다.
#
# - State-gov(주 정부) - 27.7%
# - Private - 22%
# - ? - 10%
# - Without-pay - 0.0
# - Never-worked - 0.0
#
# - ?데이터는 missingvalue -> 삭제할지 채워넣을지 고민해봐야할 것 같다.

# %%
train[train.workclass == "Without-pay"] #전부다 저임금
# Out:
#           id  age    workclass  fnlwgt     education  education_num  \
# 1427    1427   29  Without-pay  212588  Some-college             10
# 1739    1739   65  Without-pay  172949       HS-grad              9
# 5787    5787   19  Without-pay   43887       HS-grad              9
# 7966    7966   52  Without-pay  198262       HS-grad              9
# 12618  12618   19  Without-pay  344858       HS-grad              9
# 13834  13834   68  Without-pay  174695  Some-college             10
# 17380  17380   22  Without-pay  302347       HS-grad              9
# 19047  19047   72  Without-pay  121004       HS-grad              9
# 19515  19515   62  Without-pay  159908  Some-college             10
# 22637  22637   62  Without-pay  170114    Assoc-acdm             12
# 23054  23054   46  Without-pay  142210       HS-grad              9
#
#               marital_status         occupation relationship   race     sex  \
# 1427      Married-civ-spouse    Farming-fishing    Own-child  White    Male
# 1739      Married-civ-spouse   Transport-moving      Husband  White    Male
# 5787           Never-married    Farming-fishing    Own-child  White    Male
# 7966      Married-civ-spouse       Adm-clerical         Wife  White  Female
# 12618          Never-married    Farming-fishing    Own-child  White    Male
# 13834  Married-spouse-absent    Farming-fishing    Unmarried  White  Female
# 17380          Never-married  Handlers-cleaners    Own-child  White    Male
# 19047     Married-civ-spouse      Other-service      Husband  White    Male
# 19515     Married-civ-spouse       Adm-clerical         Wife  White  Female
# 22637     Married-civ-spouse    Farming-fishing      Husband  White    Male
# 23054     Married-civ-spouse  Machine-op-inspct         Wife  White  Female
#
#        capital_gain  capital_loss  hours_per_week native_country income
# 1427              0             0              65  United-States  <=50K
# 1739           2414             0              20  United-States  <=50K
# 5787              0             0              10  United-States  <=50K
# 7966              0             0              30  United-States  <=50K
# 12618             0             0              20  United-States  <=50K
# 13834             0             0              25  United-States  <=50K
# 17380          4416             0              40  United-States  <=50K
# 19047             0             0              55  United-States  <=50K
# 19515             0             0              16  United-States  <=50K
# 22637             0             0              50  United-States  <=50K
# 23054             0             0              25  United-States  <=50K

# %%
train[train.workclass == "Never-worked"] #전부다 저임금
# Out:
#           id  age     workclass  fnlwgt     education  education_num  \
# 7929    7929   17  Never-worked  237272          10th              6
# 8698    8698   18  Never-worked  157131          11th              7
# 13008  13008   18  Never-worked  153663  Some-college             10
# 15076  15076   20  Never-worked  462294  Some-college             10
# 17531  17531   18  Never-worked  206359          10th              6
# 24153  24153   23  Never-worked  188535       7th-8th              4
#
#       marital_status occupation   relationship   race     sex  capital_gain  \
# 7929   Never-married          ?      Own-child  White    Male             0
# 8698   Never-married          ?      Own-child  White  Female             0
# 13008  Never-married          ?      Own-child  White    Male             0
# 15076  Never-married          ?      Own-child  Black    Male             0
# 17531  Never-married          ?      Own-child  White    Male             0
# 24153       Divorced          ?  Not-in-family  White    Male             0
#
#        capital_loss  hours_per_week native_country income
# 7929              0              30  United-States  <=50K
# 8698              0              10  United-States  <=50K
# 13008             0               4  United-States  <=50K
# 15076             0              40  United-States  <=50K
# 17531             0              40  United-States  <=50K
# 24153             0              35  United-States  <=50K

# %% [markdown]
# ### education_num

# %%
train[['education_num', 'education','income']].groupby(['education_num','education'],as_index = False).count().drop('income', axis = 1)
# Out:
#     education_num     education
# 0               1     Preschool
# 1               2       1st-4th
# 2               3       5th-6th
# 3               4       7th-8th
# 4               5           9th
# 5               6          10th
# 6               7          11th
# 7               8          12th
# 8               9       HS-grad
# 9              10  Some-college
# 10             11     Assoc-voc
# 11             12    Assoc-acdm
# 12             13     Bachelors
# 13             14       Masters
# 14             15   Prof-school
# 15             16     Doctorate

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 7))
col = 'education_num'
value_counts = train[col].value_counts().sort_index()
sns.countplot(x=col, data=train, palette="Set2", edgecolor='black', order = value_counts.index)
plt.xticks

for i, v in value_counts.reset_index().iterrows():
    ax.text(i-0.1, v[col]+150 , v[col])

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 7))
value_counts = train[col].value_counts().sort_index()
sns.countplot(x=col, hue='income', data=train, palette="Set2", edgecolor='black', order = value_counts.index);

# %%
def portion_income(column):
    train[column] = train[column].astype('str')
    col_lst = train[column].unique().tolist()
    df = train[[column,'income']]

    for x in col_lst:
        locals()["high" + '_' + x] = df[(df[column] == x) & (df.income == ">50K")]
        locals()["low" + '_' + x]  = df[(df[column] == x) & (df.income == "<=50K")]
    col_name = []
    col_name_value = []
    for x in col_lst:
        col_name.append(x)
        col_name_value.append(len(locals()["high" + '_' + x]) / (len(locals()["high" + '_' + x]) + len(locals()["low" + '_' + x])))
        #print(x , len(locals()["high" + '_' + x]) / (len(locals()["high" + '_' + x]) + len(locals()["low" + '_' + x])))
    data = pd.DataFrame({"name" : col_name, "value" : col_name_value }).sort_values(by = 'value', ascending = False)
    return data

# %%
portion_income('education')
#상위 4개 / 그다음 2개 / 그다음 2개 / 나머지
# Out:
#             name     value
# 13     Doctorate  0.734177
# 9    Prof-school  0.733906
# 11       Masters  0.561684
# 3      Bachelors  0.415516
# 12     Assoc-voc  0.255474
# 7     Assoc-acdm  0.255344
# 2   Some-college  0.192586
# 0        HS-grad  0.158544
# 8           10th  0.072503
# 14          12th  0.072423
# 4           11th  0.059653
# 10       7th-8th  0.057426
# 1            9th  0.052632
# 6        5th-6th  0.049057
# 5        1st-4th  0.037313
# 15     Preschool  0.000000

# %%
education_protion = portion_income("education")

# %% [markdown]
# - Preschool < 1st-4th < 5th-6th < 7th-8th < 9th < 10th < 11th < 12th < HS-grad < Prof-school < Assoc-acdm < Assoc-voc < Some-college < Bachelors < Masters < Doctorate.
# - Doctorate - 박사학위
# - Prof-school -
# - Masters - 석사
# - Bachelors - 학사
# - Some-college
# - "일부 대학"(종종 "일부 대학, 학위 없음")은 주로 취업 통계의 범주입니다. 평균적으로 대학을 시작했지만 졸업하지 않은 사람은 고등학교 졸업장 만있는 사람보다 더 많이 벌고 실업률이 적지 만 준 학사 학위를 가진 사람만큼 좋지는 않습니다.
#
# - HS-grad - 고등학교 졸업
# - preschool - 취학 전의

# %% [markdown]
# ### martial_status

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 7))
col = 'marital_status'
value_counts = train[col].value_counts()
sns.countplot(x=col, data=train, palette="Set2", edgecolor='black', order = value_counts.index)

for i, v in value_counts.reset_index().iterrows():
    ax.text(i-0.1, v[col]+150 , v[col])

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 7))
value_counts = train[col].value_counts()
sns.countplot(x=col, hue='income', data=train, palette="Set2", edgecolor='black', order = value_counts.index);

# %%
portion_income('marital_status')
# Out:
#                     name     value
# 6      Married-AF-spouse  0.526316
# 0     Married-civ-spouse  0.448789
# 4               Divorced  0.104921
# 5                Widowed  0.087940
# 3  Married-spouse-absent  0.080838
# 2              Separated  0.065375
# 1          Never-married  0.046802

# %%
marital_status_protion = portion_income("marital_status")

# %% [markdown]
# ### occupation

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 7))
col = 'occupation'
value_counts = train[col].value_counts()
sns.countplot(x=col, data=train, palette="Set2", edgecolor='black', order = value_counts.index)
plt.xticks(rotation=45)

for i, v in value_counts.reset_index().iterrows():
    ax.text(i-0.12, v[col]+50 , v[col])

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
value_counts = train[col].value_counts()
sns.countplot(y=col, hue='income', data=train, palette="Set2", edgecolor='black', order = value_counts.index);

# %%
train[train.occupation == 'Armed-Forces']
# Out:
#        age    workclass  fnlwgt     education  education_num  \
# 3046    29  Federal-gov  301010  Some-college             10
# 3551    23  Federal-gov  163870  Some-college             10
# 10992   23  Federal-gov  173851       HS-grad              9
# 12068   30  Federal-gov   76313       HS-grad              9
# 12242   34  Federal-gov  172716          12th              8
# 24440   24  Federal-gov  287988     Bachelors             13
# 24982   24  Federal-gov  191073       HS-grad              9
#
#            marital_status    occupation    relationship                race  \
# 3046        Never-married  Armed-Forces   Not-in-family               Black
# 3551        Never-married  Armed-Forces  Other-relative               White
# 10992       Never-married  Armed-Forces   Not-in-family               White
# 12068  Married-civ-spouse  Armed-Forces  Other-relative  Amer-Indian-Eskimo
# 12242  Married-civ-spouse  Armed-Forces         Husband               White
# 24440       Never-married  Armed-Forces   Not-in-family               White
# 24982       Never-married  Armed-Forces       Own-child               White
#
#         sex  capital_gain  capital_loss  hours_per_week native_country income  \
# 3046   Male             0             0              60  United-States  <=50K
# 3551   Male             0             0              40  United-States  <=50K
# 10992  Male             0             0               8  United-States  <=50K
# 12068  Male             0             0              48  United-States  <=50K
# 12242  Male             0             0              40  United-States  <=50K
# 24440  Male             0             0              40  United-States  <=50K
# 24982  Male             0             0              40  United-States  <=50K
#
#        workclass_income_up_portion
# 3046                     38.169935
# 3551                     38.169935
# 10992                    38.169935
# 12068                    38.169935
# 12242                    38.169935
# 24440                    38.169935
# 24982                    38.169935

# %%
portion_income('occupation')
#Exec-managerial 경영진
#Prof-specialty 전문직
#Protective-serv 보호 서비스
#Tech-support 기술지원



#Adm-clerical 임시 사무원

#Armed-Forces 군인 월급이 50k ? 7명? - 고려해봐야한다.
# Out:
#                  name     value
# 9     Exec-managerial  0.490758
# 3      Prof-specialty  0.451271
# 11    Protective-serv  0.319923
# 12       Tech-support  0.301887
# 0               Sales  0.270514
# 5        Craft-repair  0.226242
# 10   Transport-moving  0.199213
# 4        Adm-clerical  0.134764
# 1   Machine-op-inspct  0.126422
# 8     Farming-fishing  0.116071
# 6                   ?  0.101459
# 7   Handlers-cleaners  0.065018
# 2       Other-service  0.041889
# 13    Priv-house-serv  0.008130
# 14       Armed-Forces  0.000000

# %% [markdown]
# ### Relationship

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 7))
col = 'relationship'
value_counts = train[col].value_counts()
sns.countplot(x=col, data=train, palette="Set2", edgecolor='black', order = value_counts.index)

for i, v in value_counts.reset_index().iterrows():
    ax.text(i-0.1, v[col]+150 , v[col])

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
value_counts = train[col].value_counts()
sns.countplot(x=col, hue='income', data=train, palette="Set2", edgecolor='black', order = value_counts.index);

# %%
portion_income('relationship')
# Out:
#      relationship  relationship_income_up_portion
# 4            Wife                        0.483333
# 0         Husband                        0.449673
# 2   Not-in-family                        0.104795
# 3       Unmarried                        0.064234
# 5  Other-relative                        0.042471
# 1       Own-child                        0.012686

# %%
relationship_protion = portion_income("relationship")

# %% [markdown]
# ### race

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
col = 'race'
value_counts = train[col].value_counts()
sns.countplot(x=col, data=train, palette="Set2", edgecolor='black', order = value_counts.index)

for i, v in value_counts.reset_index().iterrows():
    ax.text(i-0.1, v[col]+150 , v[col])

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
value_counts = train[col].value_counts()
sns.countplot(x=col, hue='income', data=train, palette="Set2", edgecolor='black', order = value_counts.index);

# %%
portion_income('race')
# Out:
#                  race  race_income_up_portion
# 2  Asian-Pac-Islander                0.268750
# 0               White                0.257271
# 1               Black                0.121971
# 4  Amer-Indian-Eskimo                0.114173
# 3               Other                0.088235

# %%
race_protion = portion_income("race")

# %% [markdown]
# ### sex

# %%
fig, ax = plt.subplots(1, 1, figsize=(7, 4))
col = 'sex'
value_counts = train[col].value_counts()
sns.countplot(x=col, data=train, palette="Set2", edgecolor='black', order = value_counts.index)

for i, v in value_counts.reset_index().iterrows():
    ax.text(i-0.05, v[col]+150 , v[col])

# %%
fig, ax = plt.subplots(1, 1, figsize=(7, 4))
value_counts = train[col].value_counts()
sns.countplot(x=col, hue='income', data=train, palette="Set2", edgecolor='black', order = value_counts.index);

# %%
portion_income('sex')
# Out:
#      name     value
# 0    Male  0.306143
# 1  Female  0.111241

# %%
sex_protion = portion_income("sex")

# %%
sex_protion
# Out:
#       sex  sex_income_up_portion
# 0    Male               0.306143
# 1  Female               0.111241

# %% [markdown]
# ### age

# %%
fig, ax = plt.subplots(1, 1, figsize=(24, 4))
col = 'age'
value_counts = train[col].value_counts()
sns.countplot(x=col, data=train, palette="Set2", edgecolor='black')

for i, v in value_counts.reset_index().iterrows():
    ax.text(i-0.05, v[col]+150 , v[col])

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 4))
value_counts = train[col].value_counts()
sns.countplot(x=col, hue='income', data=train, palette="Set2", edgecolor='black');

# %%
위의 그래프를 보면 47까지 인구수가 유지가 조금은 되는것 같다.
나이가 21부터 47까지 인구수에 관계없이 수입이 많은사람이 늘어난다.


나이가 52부터 인구수가 감소한다.
나이가 52부터 



portion_income('age').sort_values(by = ['age'])
17 ~ 20
21 ~ 24
24 ~ 27
27 ~ 35
36 ~ 47
48 ~ 52
53 ~ 61
62 ~ 71
72 ~ 80
81 ~ 90
# Out:
#    age  age_income_up_portion
# 1   17                  0.000
# 2   18                  0.000
# 37  19                  0.002
# 21  20                  0.000
# 3   21                  0.004
# 22  22                  0.016
# 20  23                  0.013
# 4   24                  0.037
# 26  25                  0.064
# 15  26                  0.089
# 23  27                  0.095
# 39  28                  0.141
# 16  29                  0.165
# 47  30                  0.209
# 18  31                  0.225
# 13  32                  0.236
# 40  33                  0.215
# 9   34                  0.273
# 36  35                  0.254
# 41  36                  0.317
# 6   37                  0.337
# 28  38                  0.346
# 12  39                  0.343
# 0   40                  0.336
# 8   41                  0.348
# 44  42                  0.351
# 5   43                  0.366
# 10  44                  0.378
# 32  45                  0.393
# 19  46                  0.390
# 7   47                  0.410
# 49  48                  0.399
# 46  49                  0.370
# 11  50                  0.424
# 24  51                  0.415
# 33  52                  0.389
# 17  53                  0.410
# 14  54                  0.400
# 52  55                  0.353
# 48  56                  0.323
# 25  57                  0.380
# 31  58                  0.349
# 45  59                  0.367
# 51  60                  0.327
# 50  61                  0.317
# 43  62                  0.252
# 42  63                  0.254
# 30  64                  0.239
# 35  65                  0.248
# 29  66                  0.220
# 34  67                  0.242
# 38  68                  0.231
# 54  69                  0.176
# 59  70                  0.176
# 57  71                  0.245
# 53  72                  0.153
# 65  73                  0.157
# 55  74                  0.244
# 64  75                  0.139
# 27  76                  0.081
# 69  77                  0.130
# 61  78                  0.238
# 63  79                  0.389
# 60  80                  0.100
# 56  81                  0.125
# 67  82                  0.000
# 66  83                  0.400
# 58  84                  0.111
# 68  85                  0.000
# 72  86                  0.000
# 70  87                  0.000
# 71  88                  0.000
# 62  90                  0.167

# %%
age_protion = portion_income("age")

# %%
train.age.apply(lambda x : x < 22   )
train.age.apply(lambda x : 22 =< x < )
train.age.apply(lambda x : x )
train.age.apply(lambda x : x )
# Out:
#           id  age         workclass  fnlwgt     education  education_num      marital_status         occupation   relationship   race     sex  capital_gain  capital_loss  hours_per_week native_country income
# 0          0   40           Private  168538       HS-grad              9  Married-civ-spouse              Sales        Husband  White    Male             0             0              60  United-States   >50K
# 1          1   17           Private  101626           9th              5       Never-married  Machine-op-inspct      Own-child  White    Male             0             0              20  United-States  <=50K
# 2          2   18           Private  353358  Some-college             10       Never-married      Other-service      Own-child  White    Male             0             0              16  United-States  <=50K
# 3          3   21           Private  151158  Some-college             10       Never-married     Prof-specialty      Own-child  White  Female             0             0              25  United-States  <=50K
# 4          4   24           Private  122234  Some-college             10       Never-married       Adm-clerical  Not-in-family  Black  Female             0             0              20              ?  <=50K
# ...      ...  ...               ...     ...           ...            ...                 ...                ...            ...    ...     ...           ...           ...             ...            ...    ...
# 26044  26044   57           Private  250201          11th              7  Married-civ-spouse      Other-service        Husband  White    Male             0             0              52  United-States  <=50K
# 26045  26045   23           Private  238092     Bachelors             13       Never-married     Prof-specialty      Own-child  White    Male             0             0              40  United-States  <=50K
# 26046  26046   78                 ?  165694       Masters             14             Widowed                  ?  Not-in-family  White  Female             0             0              15  United-States  <=50K
# 26047  26047   26  Self-emp-not-inc  151626       HS-grad              9       Never-married     Prof-specialty      Own-child  Black  Female             0             0              40  United-States  <=50K
# 26048  26048   20                 ?   99891  Some-college             10       Never-married                  ?      Own-child  White  Female             0             0              30  United-States  <=50K
#
# [26049 rows x 16 columns]

# %% [markdown]
# ### hours_per_week

# %% [markdown]
# - 직업마다 근무시간에 따른 수입이 다를것 같다.

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 4))
col = 'hours_per_week'
value_counts = train[col].value_counts()
sns.countplot(x=col, data=train, palette="Set2", edgecolor='black')

for i, v in value_counts.reset_index().iterrows():
    ax.text(i-0.05, v[col]+150 , v[col])
#근무시간에 5의 배수일경우의 데이터 수가 많다.

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 4))
value_counts = train[col].value_counts()
sns.countplot(x=col, hue='income', data=train, palette="Set2", edgecolor='black');

# %%
portion_income('hours_per_week')
# Out:
#    name     value
# 92   61  1.000000
# 76   67  0.750000
# 84   76  0.666667
# 86   73  0.500000
# 65   57  0.500000
# ..  ...       ...
# 79   82  0.000000
# 78   86  0.000000
# 77   21  0.000000
# 56   23  0.000000
# 68   19  0.000000
#
# [93 rows x 2 columns]

# %%
hours_per_week_protion = portion_income("hours_per_week")

# %% [markdown]
# # EDA -3

# %%
sex_occupation = train[['sex', 'occupation']]

# %%
#특정 컬럼에서 특정항목값의 수익이 높은 사람의 수 / 특정컬럼에서 특정항목값 총 사람의 수 => 수입이 높은 사람의 비율
def portion_income_sex_occupation(column):
    train[column] = train[column].astype('str')
    col_lst = train[column].unique().tolist()
    df = train[[column,'sex']]

    for x in col_lst:
        locals()["ma" + '_' + x] = df[(df[column] == x) & (df.sex == "Male")]
        locals()["fe" + '_' + x]  = df[(df[column] == x) & (df.sex == "Female")]
    col_name = []
    col_name_value = []
    for x in col_lst:
        col_name.append(x)
        col_name_value.append(len(locals()["ma" + '_' + x]) / (len(locals()["ma" + '_' + x]) + len(locals()["fe" + '_' + x])))
        #print(x , len(locals()["high" + '_' + x]) / (len(locals()["high" + '_' + x]) + len(locals()["low" + '_' + x])))
    data = pd.DataFrame({"name" : col_name, "value" : col_name_value }).sort_values(by = 'value', ascending = False)
    data.columns = [column, '{}_income_up_portion'.format(column)]
    return data

# %%
portion_income_sex_occupation("occupation")
#해당 직업에서 남자의 비율
# Out:
#            occupation  occupation_income_up_portion
# 14       Armed-Forces                      1.000000
# 5        Craft-repair                      0.946658
# 10   Transport-moving                      0.944882
# 8     Farming-fishing                      0.943878
# 11    Protective-serv                      0.902299
# 7   Handlers-cleaners                      0.882784
# 1   Machine-op-inspct                      0.728192
# 9     Exec-managerial                      0.712877
# 0               Sales                      0.657438
# 3      Prof-specialty                      0.634383
# 12       Tech-support                      0.623989
# 6                   ?                      0.549735
# 2       Other-service                      0.460396
# 4        Adm-clerical                      0.326182
# 13    Priv-house-serv                      0.040650

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 7))
col = 'occupation'
value_counts = train[col].value_counts()
sns.countplot(x=col, data=train, palette="Set2", edgecolor='black', order = value_counts.index)
plt.xticks(rotation=45)
# bar 상단에 count 숫자로 입력
for i, v in value_counts.reset_index().iterrows():
    ax.text(i-0.1, v[col]+150 , v[col])

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 7))
value_counts = train[col].value_counts()
plt.xticks(rotation=45)
sns.countplot(x=col, hue='sex', data=train, palette="Set2", edgecolor='black', order = value_counts.index);

# %%
sex_occupation = train[['sex', 'occupation']]

# %% [markdown]
# Adm-clerical(임시 사무원)은 여성의 비중이 매우 높다.
# other-service(서비스)는 여성의 비중이 남성보다 높다.
#
# 그걸 제외하고 나머지는 다 남성이 해당직업에 차지하는 비율이 높다.
#
# 그중에서

# %% [markdown]
# ### 컬럼간 수치형데이터 시각화

# %%
train.income = train.income.apply(lambda x : 1 if x == '>50K' else x)
train.income = train.income.apply(lambda x : 0 if x == '<=50K' else x)

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import datasets
from pandas.plotting import scatter_matrix

#ploting scatter graph of species comparing all features to each other
scatter_matrix(train, c=train['income'],marker='o', s=10,alpha=.8,figsize=(40, 40))
plt.show()

# %% [markdown]
# # feature

# %% [markdown]
# ### capital gain 뜯어먹자

# %%
import qgrid
qgrid_widget = qgrid.show_grid(train,show_toolbar=True)
qgrid_widget
#검색조건 : 수입이 낮은경우 / capital gain이 제일 높은 순으로 정렬
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %% [markdown]
# - 수입이 낮은 사람의 경우 capital_gain이 41310이 최대다

# %%
qgrid_widget = qgrid.show_grid(train,show_toolbar=True)
qgrid_widget
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %% [markdown]
# - 즉 capital_gain이 41310 이상인 경우에는 죄다 수입이 높은 집단으로 분류되었다

# %% [markdown]
# - capital_gain이 99999인 사람은 어떤사람일까

# %%
qgrid_widget = qgrid.show_grid(train,show_toolbar=True)
qgrid_widget
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
train[train.capital_gain > 41310] #즉 capital_gain이 41310의 바로 윗 값은 99999
# Out:
#           id  age         workclass  fnlwgt     education  education_num  \
# 227      227   24                 ?  151153  Some-college             10
# 430      430   55           Private  408537           9th              5
# 848      848   32           Private  330715       HS-grad              9
# 852      852   66           Private  115498     Bachelors             13
# 1209    1209   37         Local-gov  287306    Assoc-acdm             12
# ...      ...  ...               ...     ...           ...            ...
# 25535  25535   55           Private  197399       Masters             14
# 25648  25648   64      Self-emp-inc  185912   Prof-school             15
# 25705  25705   41           Private  115932  Some-college             10
# 25824  25824   50  Self-emp-not-inc  132716   Prof-school             15
# 25987  25987   63           Private  118798       HS-grad              9
#
#            marital_status       occupation   relationship                race  \
# 227         Never-married                ?  Not-in-family  Asian-Pac-Islander
# 430              Divorced     Craft-repair      Unmarried               White
# 848    Married-civ-spouse     Craft-repair        Husband               White
# 852    Married-civ-spouse  Exec-managerial        Husband               White
# 1209   Married-civ-spouse   Prof-specialty           Wife               Black
# ...                   ...              ...            ...                 ...
# 25535  Married-civ-spouse  Exec-managerial        Husband               White
# 25648  Married-civ-spouse   Prof-specialty        Husband               White
# 25705  Married-civ-spouse  Exec-managerial        Husband               White
# 25824  Married-civ-spouse  Exec-managerial        Husband               White
# 25987  Married-civ-spouse     Craft-repair        Husband               White
#
#           sex  capital_gain  capital_loss  hours_per_week native_country  \
# 227      Male         99999             0              50          South
# 430    Female         99999             0              37  United-States
# 848      Male         99999             0              40  United-States
# 852      Male         99999             0              55              ?
# 1209   Female         99999             0              40              ?
# ...       ...           ...           ...             ...            ...
# 25535    Male         99999             0              55  United-States
# 25648    Male         99999             0              35  United-States
# 25705    Male         99999             0              50  United-States
# 25824    Male         99999             0              50  United-States
# 25987    Male         99999             0              40  United-States
#
#       income
# 227     >50K
# 430     >50K
# 848     >50K
# 852     >50K
# 1209    >50K
# ...      ...
# 25535   >50K
# 25648   >50K
# 25705   >50K
# 25824   >50K
# 25987   >50K
#
# [127 rows x 16 columns]

# %% [markdown]
# #### 확실한 up50k 는 capital_gain이 99999인경우

# %% [markdown]
# #### education이 preschool ~ 12th 까지 거의 대부분 수입이 낮은집단

# %%
qgrid_widget = qgrid.show_grid(train,show_toolbar=True)
qgrid_widget
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
qgrid_widget = qgrid.show_grid(train,show_toolbar=True)
qgrid_widget
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
qgrid_widget = qgrid.show_grid(train,show_toolbar=True)
qgrid_widget
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %% [markdown]
# # Modeliing

# %%
train.drop(['id'], axis=1, inplace=True)
test.drop(['id'], axis=1, inplace=True)

# %%
y = train['income'] != '<=50K'
X = train.drop(['income'], axis=1)

# %%
# 라벨 인코더 생성
LE_encoder = OrdinalEncoder(list(X.columns))

# train, test 데이터에 인코딩 적용
X = LE_encoder.fit_transform(X, y)
test = LE_encoder.transform(test)

# %%
NFOLDS = 5
folds = KFold(n_splits=NFOLDS)

columns = X.columns
splits = folds.split(X, y)
y_preds = np.zeros(test.shape[0])

feature_importances = pd.DataFrame()
feature_importances['feature'] = columns

# %%
model = LGBMClassifier(objective='binary', verbose=400, random_state=91)


for fold_n, (train_index, valid_index) in enumerate(splits):
    print('Fold: ', fold_n+1)
    X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
    y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]

    evals = [(X_train, y_train), (X_valid, y_valid)]
    model.fit(X_train, y_train, eval_metric='f1', eval_set=evals, verbose=True)
    
    feature_importances[f'fold_{fold_n + 1}'] = model.feature_importances_
        
    y_preds += model.predict(test).astype(int) / NFOLDS
    
    #del X_train, X_valid, y_train, y_valid
    gc.collect()
# Out:
# Fold:  1
# [LightGBM] [Info] Number of positive: 5057, number of negative: 15782
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.905562
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.278634
# [LightGBM] [Debug] init for col-wise cost 0.001279 seconds, init for row-wise cost 0.002618 seconds
# [LightGBM] [Debug] col-wise cost 0.000315 seconds, row-wise cost 0.000206 seconds
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001800 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Debug] Using Sparse Multi-Val Bin
# [LightGBM] [Info] Total Bins 669
# [LightGBM] [Info] Number of data points in the train set: 20839, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.242670 -> initscore=-1.138097
# [LightGBM] [Info] Start training from score -1.138097
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [1]	training's binary_logloss: 0.51029	valid_1's binary_logloss: 0.507521
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [2]	training's binary_logloss: 0.477769	valid_1's binary_logloss: 0.475498
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [3]	training's binary_logloss: 0.451924	valid_1's binary_logloss: 0.450099
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [4]	training's binary_logloss: 0.431056	valid_1's binary_logloss: 0.429931
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [5]	training's binary_logloss: 0.413344	valid_1's binary_logloss: 0.412961
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [6]	training's binary_logloss: 0.398448	valid_1's binary_logloss: 0.398553
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [7]	training's binary_logloss: 0.385494	valid_1's binary_logloss: 0.386001
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [8]	training's binary_logloss: 0.374216	valid_1's binary_logloss: 0.375402
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [9]	training's binary_logloss: 0.364543	valid_1's binary_logloss: 0.366755
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [10]	training's binary_logloss: 0.35588	valid_1's binary_logloss: 0.358671
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [11]	training's binary_logloss: 0.348202	valid_1's binary_logloss: 0.35154
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [12]	training's binary_logloss: 0.341274	valid_1's binary_logloss: 0.345249
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [13]	training's binary_logloss: 0.33509	valid_1's binary_logloss: 0.339437
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [14]	training's binary_logloss: 0.329677	valid_1's binary_logloss: 0.33427
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [15]	training's binary_logloss: 0.324492	valid_1's binary_logloss: 0.329796
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [16]	training's binary_logloss: 0.3199	valid_1's binary_logloss: 0.325764
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [17]	training's binary_logloss: 0.315882	valid_1's binary_logloss: 0.322228
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [18]	training's binary_logloss: 0.31209	valid_1's binary_logloss: 0.318644
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [19]	training's binary_logloss: 0.308411	valid_1's binary_logloss: 0.31539
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [20]	training's binary_logloss: 0.305159	valid_1's binary_logloss: 0.312473
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [21]	training's binary_logloss: 0.302003	valid_1's binary_logloss: 0.309681
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [22]	training's binary_logloss: 0.299266	valid_1's binary_logloss: 0.30722
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [23]	training's binary_logloss: 0.296897	valid_1's binary_logloss: 0.305319
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [24]	training's binary_logloss: 0.294603	valid_1's binary_logloss: 0.303486
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [25]	training's binary_logloss: 0.292475	valid_1's binary_logloss: 0.301975
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [26]	training's binary_logloss: 0.290534	valid_1's binary_logloss: 0.300618
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [27]	training's binary_logloss: 0.288833	valid_1's binary_logloss: 0.299573
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [28]	training's binary_logloss: 0.287146	valid_1's binary_logloss: 0.298381
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 16
# [29]	training's binary_logloss: 0.285372	valid_1's binary_logloss: 0.297201
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [30]	training's binary_logloss: 0.28389	valid_1's binary_logloss: 0.296397
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 17
# [31]	training's binary_logloss: 0.281957	valid_1's binary_logloss: 0.295272
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [32]	training's binary_logloss: 0.280696	valid_1's binary_logloss: 0.294643
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [33]	training's binary_logloss: 0.279391	valid_1's binary_logloss: 0.293916
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [34]	training's binary_logloss: 0.278074	valid_1's binary_logloss: 0.293155
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [35]	training's binary_logloss: 0.276403	valid_1's binary_logloss: 0.292288
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 16
# [36]	training's binary_logloss: 0.275031	valid_1's binary_logloss: 0.291775
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [37]	training's binary_logloss: 0.27403	valid_1's binary_logloss: 0.291088
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [38]	training's binary_logloss: 0.273075	valid_1's binary_logloss: 0.290842
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [39]	training's binary_logloss: 0.271392	valid_1's binary_logloss: 0.289727
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [40]	training's binary_logloss: 0.270045	valid_1's binary_logloss: 0.288953
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [41]	training's binary_logloss: 0.26873	valid_1's binary_logloss: 0.28816
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [42]	training's binary_logloss: 0.267817	valid_1's binary_logloss: 0.287775
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [43]	training's binary_logloss: 0.266709	valid_1's binary_logloss: 0.287221
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 16
# [44]	training's binary_logloss: 0.265871	valid_1's binary_logloss: 0.286894
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 16
# [45]	training's binary_logloss: 0.26476	valid_1's binary_logloss: 0.286392
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [46]	training's binary_logloss: 0.263948	valid_1's binary_logloss: 0.286001
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [47]	training's binary_logloss: 0.263274	valid_1's binary_logloss: 0.285576
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [48]	training's binary_logloss: 0.262483	valid_1's binary_logloss: 0.285591
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [49]	training's binary_logloss: 0.261517	valid_1's binary_logloss: 0.285074
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [50]	training's binary_logloss: 0.260866	valid_1's binary_logloss: 0.284939
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [51]	training's binary_logloss: 0.260104	valid_1's binary_logloss: 0.284512
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [52]	training's binary_logloss: 0.259358	valid_1's binary_logloss: 0.28419
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [53]	training's binary_logloss: 0.258707	valid_1's binary_logloss: 0.283977
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 16
# [54]	training's binary_logloss: 0.258137	valid_1's binary_logloss: 0.284006
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 18
# [55]	training's binary_logloss: 0.257517	valid_1's binary_logloss: 0.283801
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [56]	training's binary_logloss: 0.256912	valid_1's binary_logloss: 0.283825
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [57]	training's binary_logloss: 0.256297	valid_1's binary_logloss: 0.283842
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [58]	training's binary_logloss: 0.255495	valid_1's binary_logloss: 0.283564
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [59]	training's binary_logloss: 0.25492	valid_1's binary_logloss: 0.283288
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 21
# [60]	training's binary_logloss: 0.254401	valid_1's binary_logloss: 0.283251
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [61]	training's binary_logloss: 0.253836	valid_1's binary_logloss: 0.283169
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [62]	training's binary_logloss: 0.253101	valid_1's binary_logloss: 0.283065
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [63]	training's binary_logloss: 0.252618	valid_1's binary_logloss: 0.283113
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [64]	training's binary_logloss: 0.252146	valid_1's binary_logloss: 0.283048
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [65]	training's binary_logloss: 0.251666	valid_1's binary_logloss: 0.282998
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [66]	training's binary_logloss: 0.251031	valid_1's binary_logloss: 0.282738
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [67]	training's binary_logloss: 0.250371	valid_1's binary_logloss: 0.282297
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [68]	training's binary_logloss: 0.249761	valid_1's binary_logloss: 0.282057
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [69]	training's binary_logloss: 0.249227	valid_1's binary_logloss: 0.282013
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [70]	training's binary_logloss: 0.248602	valid_1's binary_logloss: 0.281826
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [71]	training's binary_logloss: 0.248155	valid_1's binary_logloss: 0.281754
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 16
# [72]	training's binary_logloss: 0.24771	valid_1's binary_logloss: 0.281513
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [73]	training's binary_logloss: 0.247299	valid_1's binary_logloss: 0.281297
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [74]	training's binary_logloss: 0.246882	valid_1's binary_logloss: 0.281194
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [75]	training's binary_logloss: 0.246406	valid_1's binary_logloss: 0.28124
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [76]	training's binary_logloss: 0.245871	valid_1's binary_logloss: 0.281128
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [77]	training's binary_logloss: 0.245482	valid_1's binary_logloss: 0.281033
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [78]	training's binary_logloss: 0.244994	valid_1's binary_logloss: 0.280908
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [79]	training's binary_logloss: 0.244619	valid_1's binary_logloss: 0.280747
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [80]	training's binary_logloss: 0.244274	valid_1's binary_logloss: 0.280939
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [81]	training's binary_logloss: 0.24388	valid_1's binary_logloss: 0.280806
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [82]	training's binary_logloss: 0.243433	valid_1's binary_logloss: 0.280731
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [83]	training's binary_logloss: 0.242991	valid_1's binary_logloss: 0.280477
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 18
# [84]	training's binary_logloss: 0.24256	valid_1's binary_logloss: 0.280443
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [85]	training's binary_logloss: 0.24207	valid_1's binary_logloss: 0.280491
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [86]	training's binary_logloss: 0.241483	valid_1's binary_logloss: 0.280382
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 16
# [87]	training's binary_logloss: 0.241019	valid_1's binary_logloss: 0.280247
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [88]	training's binary_logloss: 0.240661	valid_1's binary_logloss: 0.280256
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [89]	training's binary_logloss: 0.240356	valid_1's binary_logloss: 0.280136
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 17
# [90]	training's binary_logloss: 0.240005	valid_1's binary_logloss: 0.280001
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [91]	training's binary_logloss: 0.239645	valid_1's binary_logloss: 0.280011
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [92]	training's binary_logloss: 0.239341	valid_1's binary_logloss: 0.27994
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 17
# [93]	training's binary_logloss: 0.239031	valid_1's binary_logloss: 0.279877
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [94]	training's binary_logloss: 0.238643	valid_1's binary_logloss: 0.27991
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [95]	training's binary_logloss: 0.238293	valid_1's binary_logloss: 0.28009
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [96]	training's binary_logloss: 0.237809	valid_1's binary_logloss: 0.280108
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [97]	training's binary_logloss: 0.237466	valid_1's binary_logloss: 0.280036
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [98]	training's binary_logloss: 0.236987	valid_1's binary_logloss: 0.280097
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [99]	training's binary_logloss: 0.236655	valid_1's binary_logloss: 0.280071
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [100]	training's binary_logloss: 0.236144	valid_1's binary_logloss: 0.280093
# Fold:  2
# [LightGBM] [Info] Number of positive: 5042, number of negative: 15797
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.906198
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.278830
# [LightGBM] [Debug] init for col-wise cost 0.001430 seconds, init for row-wise cost 0.003184 seconds
# [LightGBM] [Debug] col-wise cost 0.000418 seconds, row-wise cost 0.000283 seconds
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002131 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Debug] Using Sparse Multi-Val Bin
# [LightGBM] [Info] Total Bins 674
# [LightGBM] [Info] Number of data points in the train set: 20839, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.241950 -> initscore=-1.142017
# [LightGBM] [Info] Start training from score -1.142017
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [1]	training's binary_logloss: 0.509407	valid_1's binary_logloss: 0.510196
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [2]	training's binary_logloss: 0.476958	valid_1's binary_logloss: 0.47826
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [3]	training's binary_logloss: 0.451339	valid_1's binary_logloss: 0.453302
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [4]	training's binary_logloss: 0.430374	valid_1's binary_logloss: 0.432489
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [5]	training's binary_logloss: 0.412645	valid_1's binary_logloss: 0.415379
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [6]	training's binary_logloss: 0.397557	valid_1's binary_logloss: 0.40072
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [7]	training's binary_logloss: 0.384774	valid_1's binary_logloss: 0.38859
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [8]	training's binary_logloss: 0.373236	valid_1's binary_logloss: 0.377182
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [9]	training's binary_logloss: 0.363471	valid_1's binary_logloss: 0.367906
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [10]	training's binary_logloss: 0.354738	valid_1's binary_logloss: 0.359537
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [11]	training's binary_logloss: 0.347098	valid_1's binary_logloss: 0.352271
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [12]	training's binary_logloss: 0.340061	valid_1's binary_logloss: 0.345598
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [13]	training's binary_logloss: 0.33416	valid_1's binary_logloss: 0.340186
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [14]	training's binary_logloss: 0.328646	valid_1's binary_logloss: 0.334699
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [15]	training's binary_logloss: 0.323762	valid_1's binary_logloss: 0.330041
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [16]	training's binary_logloss: 0.319505	valid_1's binary_logloss: 0.326048
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [17]	training's binary_logloss: 0.315548	valid_1's binary_logloss: 0.322352
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [18]	training's binary_logloss: 0.312144	valid_1's binary_logloss: 0.319238
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [19]	training's binary_logloss: 0.308675	valid_1's binary_logloss: 0.316231
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 16
# [20]	training's binary_logloss: 0.305562	valid_1's binary_logloss: 0.313356
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [21]	training's binary_logloss: 0.302354	valid_1's binary_logloss: 0.310514
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 16
# [22]	training's binary_logloss: 0.299607	valid_1's binary_logloss: 0.307932
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [23]	training's binary_logloss: 0.297047	valid_1's binary_logloss: 0.305842
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [24]	training's binary_logloss: 0.294739	valid_1's binary_logloss: 0.3038
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [25]	training's binary_logloss: 0.292493	valid_1's binary_logloss: 0.302021
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [26]	training's binary_logloss: 0.29045	valid_1's binary_logloss: 0.300491
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [27]	training's binary_logloss: 0.288706	valid_1's binary_logloss: 0.299062
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [28]	training's binary_logloss: 0.28695	valid_1's binary_logloss: 0.29759
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [29]	training's binary_logloss: 0.28538	valid_1's binary_logloss: 0.296306
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [30]	training's binary_logloss: 0.284038	valid_1's binary_logloss: 0.295407
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [31]	training's binary_logloss: 0.282586	valid_1's binary_logloss: 0.294349
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [32]	training's binary_logloss: 0.280614	valid_1's binary_logloss: 0.292683
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [33]	training's binary_logloss: 0.279398	valid_1's binary_logloss: 0.291778
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [34]	training's binary_logloss: 0.278115	valid_1's binary_logloss: 0.290938
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [35]	training's binary_logloss: 0.276961	valid_1's binary_logloss: 0.290071
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [36]	training's binary_logloss: 0.275418	valid_1's binary_logloss: 0.28887
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [37]	training's binary_logloss: 0.273928	valid_1's binary_logloss: 0.287379
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [38]	training's binary_logloss: 0.272997	valid_1's binary_logloss: 0.28708
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 17
# [39]	training's binary_logloss: 0.271963	valid_1's binary_logloss: 0.286535
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [40]	training's binary_logloss: 0.270718	valid_1's binary_logloss: 0.285624
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [41]	training's binary_logloss: 0.269836	valid_1's binary_logloss: 0.28513
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [42]	training's binary_logloss: 0.268676	valid_1's binary_logloss: 0.284183
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [43]	training's binary_logloss: 0.267775	valid_1's binary_logloss: 0.283885
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 16
# [44]	training's binary_logloss: 0.266935	valid_1's binary_logloss: 0.283427
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [45]	training's binary_logloss: 0.265981	valid_1's binary_logloss: 0.282663
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 16
# [46]	training's binary_logloss: 0.265255	valid_1's binary_logloss: 0.28224
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [47]	training's binary_logloss: 0.264322	valid_1's binary_logloss: 0.28185
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [48]	training's binary_logloss: 0.263348	valid_1's binary_logloss: 0.281126
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [49]	training's binary_logloss: 0.262556	valid_1's binary_logloss: 0.280489
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [50]	training's binary_logloss: 0.261899	valid_1's binary_logloss: 0.280407
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [51]	training's binary_logloss: 0.261117	valid_1's binary_logloss: 0.279858
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [52]	training's binary_logloss: 0.260535	valid_1's binary_logloss: 0.279839
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [53]	training's binary_logloss: 0.259843	valid_1's binary_logloss: 0.279711
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [54]	training's binary_logloss: 0.25916	valid_1's binary_logloss: 0.279442
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [55]	training's binary_logloss: 0.258392	valid_1's binary_logloss: 0.27907
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [56]	training's binary_logloss: 0.257725	valid_1's binary_logloss: 0.278644
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [57]	training's binary_logloss: 0.257135	valid_1's binary_logloss: 0.278289
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [58]	training's binary_logloss: 0.256556	valid_1's binary_logloss: 0.278172
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [59]	training's binary_logloss: 0.256058	valid_1's binary_logloss: 0.277904
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [60]	training's binary_logloss: 0.255379	valid_1's binary_logloss: 0.277735
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [61]	training's binary_logloss: 0.254615	valid_1's binary_logloss: 0.277645
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [62]	training's binary_logloss: 0.254065	valid_1's binary_logloss: 0.277588
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [63]	training's binary_logloss: 0.253427	valid_1's binary_logloss: 0.277518
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [64]	training's binary_logloss: 0.252948	valid_1's binary_logloss: 0.277329
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 16
# [65]	training's binary_logloss: 0.252333	valid_1's binary_logloss: 0.277248
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [66]	training's binary_logloss: 0.251744	valid_1's binary_logloss: 0.276956
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [67]	training's binary_logloss: 0.251217	valid_1's binary_logloss: 0.277008
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [68]	training's binary_logloss: 0.250648	valid_1's binary_logloss: 0.276657
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 19
# [69]	training's binary_logloss: 0.250175	valid_1's binary_logloss: 0.2764
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [70]	training's binary_logloss: 0.249624	valid_1's binary_logloss: 0.276351
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [71]	training's binary_logloss: 0.249175	valid_1's binary_logloss: 0.276294
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [72]	training's binary_logloss: 0.248774	valid_1's binary_logloss: 0.276379
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [73]	training's binary_logloss: 0.248201	valid_1's binary_logloss: 0.276312
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [74]	training's binary_logloss: 0.24767	valid_1's binary_logloss: 0.276276
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [75]	training's binary_logloss: 0.247221	valid_1's binary_logloss: 0.275922
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 17
# [76]	training's binary_logloss: 0.246827	valid_1's binary_logloss: 0.275802
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [77]	training's binary_logloss: 0.246412	valid_1's binary_logloss: 0.275853
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [78]	training's binary_logloss: 0.245994	valid_1's binary_logloss: 0.275837
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [79]	training's binary_logloss: 0.245542	valid_1's binary_logloss: 0.275925
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [80]	training's binary_logloss: 0.24493	valid_1's binary_logloss: 0.275774
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [81]	training's binary_logloss: 0.244292	valid_1's binary_logloss: 0.275714
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [82]	training's binary_logloss: 0.244004	valid_1's binary_logloss: 0.275771
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [83]	training's binary_logloss: 0.243585	valid_1's binary_logloss: 0.275447
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [84]	training's binary_logloss: 0.243165	valid_1's binary_logloss: 0.27523
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [85]	training's binary_logloss: 0.242666	valid_1's binary_logloss: 0.275234
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [86]	training's binary_logloss: 0.242161	valid_1's binary_logloss: 0.275215
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [87]	training's binary_logloss: 0.241745	valid_1's binary_logloss: 0.275034
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [88]	training's binary_logloss: 0.241328	valid_1's binary_logloss: 0.27509
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 16
# [89]	training's binary_logloss: 0.241022	valid_1's binary_logloss: 0.275145
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [90]	training's binary_logloss: 0.240705	valid_1's binary_logloss: 0.275133
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 17
# [91]	training's binary_logloss: 0.24034	valid_1's binary_logloss: 0.275049
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [92]	training's binary_logloss: 0.239906	valid_1's binary_logloss: 0.275204
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [93]	training's binary_logloss: 0.239481	valid_1's binary_logloss: 0.275275
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [94]	training's binary_logloss: 0.238945	valid_1's binary_logloss: 0.275414
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [95]	training's binary_logloss: 0.238581	valid_1's binary_logloss: 0.275353
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [96]	training's binary_logloss: 0.238332	valid_1's binary_logloss: 0.275503
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [97]	training's binary_logloss: 0.237903	valid_1's binary_logloss: 0.275444
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [98]	training's binary_logloss: 0.237531	valid_1's binary_logloss: 0.275439
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [99]	training's binary_logloss: 0.237227	valid_1's binary_logloss: 0.275414
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [100]	training's binary_logloss: 0.23688	valid_1's binary_logloss: 0.275543
# Fold:  3
# [LightGBM] [Info] Number of positive: 5061, number of negative: 15778
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.905682
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.278671
# [LightGBM] [Debug] init for col-wise cost 0.001503 seconds, init for row-wise cost 0.002518 seconds
# [LightGBM] [Debug] col-wise cost 0.000409 seconds, row-wise cost 0.000316 seconds
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002228 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Debug] Using Sparse Multi-Val Bin
# [LightGBM] [Info] Total Bins 671
# [LightGBM] [Info] Number of data points in the train set: 20839, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.242862 -> initscore=-1.137052
# [LightGBM] [Info] Start training from score -1.137052
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [1]	training's binary_logloss: 0.51097	valid_1's binary_logloss: 0.506048
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [2]	training's binary_logloss: 0.478567	valid_1's binary_logloss: 0.473626
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [3]	training's binary_logloss: 0.45297	valid_1's binary_logloss: 0.448089
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [4]	training's binary_logloss: 0.431971	valid_1's binary_logloss: 0.426776
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [5]	training's binary_logloss: 0.414556	valid_1's binary_logloss: 0.40941
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [6]	training's binary_logloss: 0.399739	valid_1's binary_logloss: 0.39418
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [7]	training's binary_logloss: 0.386852	valid_1's binary_logloss: 0.381152
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [8]	training's binary_logloss: 0.375737	valid_1's binary_logloss: 0.370077
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [9]	training's binary_logloss: 0.365908	valid_1's binary_logloss: 0.359931
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [10]	training's binary_logloss: 0.357237	valid_1's binary_logloss: 0.35165
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [11]	training's binary_logloss: 0.349573	valid_1's binary_logloss: 0.343931
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [12]	training's binary_logloss: 0.342624	valid_1's binary_logloss: 0.336769
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [13]	training's binary_logloss: 0.33675	valid_1's binary_logloss: 0.33111
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [14]	training's binary_logloss: 0.3315	valid_1's binary_logloss: 0.325925
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [15]	training's binary_logloss: 0.326882	valid_1's binary_logloss: 0.321409
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [16]	training's binary_logloss: 0.322192	valid_1's binary_logloss: 0.316689
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [17]	training's binary_logloss: 0.317874	valid_1's binary_logloss: 0.312398
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [18]	training's binary_logloss: 0.314303	valid_1's binary_logloss: 0.309386
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [19]	training's binary_logloss: 0.310731	valid_1's binary_logloss: 0.305768
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 16
# [20]	training's binary_logloss: 0.307004	valid_1's binary_logloss: 0.301979
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [21]	training's binary_logloss: 0.304053	valid_1's binary_logloss: 0.299177
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [22]	training's binary_logloss: 0.301478	valid_1's binary_logloss: 0.296874
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [23]	training's binary_logloss: 0.299103	valid_1's binary_logloss: 0.294922
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [24]	training's binary_logloss: 0.29676	valid_1's binary_logloss: 0.292817
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [25]	training's binary_logloss: 0.294843	valid_1's binary_logloss: 0.291061
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [26]	training's binary_logloss: 0.29284	valid_1's binary_logloss: 0.289533
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [27]	training's binary_logloss: 0.290956	valid_1's binary_logloss: 0.288148
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [28]	training's binary_logloss: 0.289247	valid_1's binary_logloss: 0.287206
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [29]	training's binary_logloss: 0.28759	valid_1's binary_logloss: 0.286063
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [30]	training's binary_logloss: 0.286214	valid_1's binary_logloss: 0.28516
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [31]	training's binary_logloss: 0.284912	valid_1's binary_logloss: 0.284523
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [32]	training's binary_logloss: 0.283724	valid_1's binary_logloss: 0.283806
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [33]	training's binary_logloss: 0.282112	valid_1's binary_logloss: 0.282285
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [34]	training's binary_logloss: 0.280879	valid_1's binary_logloss: 0.281444
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [35]	training's binary_logloss: 0.279657	valid_1's binary_logloss: 0.280572
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [36]	training's binary_logloss: 0.278438	valid_1's binary_logloss: 0.279793
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [37]	training's binary_logloss: 0.277476	valid_1's binary_logloss: 0.279379
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [38]	training's binary_logloss: 0.276472	valid_1's binary_logloss: 0.279037
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [39]	training's binary_logloss: 0.275104	valid_1's binary_logloss: 0.277913
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 16
# [40]	training's binary_logloss: 0.274082	valid_1's binary_logloss: 0.277298
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [41]	training's binary_logloss: 0.273107	valid_1's binary_logloss: 0.276667
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [42]	training's binary_logloss: 0.271973	valid_1's binary_logloss: 0.275839
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [43]	training's binary_logloss: 0.271049	valid_1's binary_logloss: 0.275362
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 19
# [44]	training's binary_logloss: 0.269924	valid_1's binary_logloss: 0.274595
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 16
# [45]	training's binary_logloss: 0.269047	valid_1's binary_logloss: 0.273987
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [46]	training's binary_logloss: 0.268218	valid_1's binary_logloss: 0.27369
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [47]	training's binary_logloss: 0.267303	valid_1's binary_logloss: 0.27284
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [48]	training's binary_logloss: 0.266612	valid_1's binary_logloss: 0.272519
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [49]	training's binary_logloss: 0.265999	valid_1's binary_logloss: 0.272427
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [50]	training's binary_logloss: 0.265229	valid_1's binary_logloss: 0.271819
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [51]	training's binary_logloss: 0.264479	valid_1's binary_logloss: 0.271288
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [52]	training's binary_logloss: 0.263767	valid_1's binary_logloss: 0.271028
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [53]	training's binary_logloss: 0.263034	valid_1's binary_logloss: 0.27063
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [54]	training's binary_logloss: 0.262243	valid_1's binary_logloss: 0.270373
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [55]	training's binary_logloss: 0.261601	valid_1's binary_logloss: 0.269888
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [56]	training's binary_logloss: 0.260899	valid_1's binary_logloss: 0.269674
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [57]	training's binary_logloss: 0.260232	valid_1's binary_logloss: 0.269247
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [58]	training's binary_logloss: 0.259629	valid_1's binary_logloss: 0.268861
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [59]	training's binary_logloss: 0.259139	valid_1's binary_logloss: 0.268821
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [60]	training's binary_logloss: 0.258628	valid_1's binary_logloss: 0.268522
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [61]	training's binary_logloss: 0.257972	valid_1's binary_logloss: 0.267874
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [62]	training's binary_logloss: 0.257404	valid_1's binary_logloss: 0.267877
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [63]	training's binary_logloss: 0.256821	valid_1's binary_logloss: 0.267714
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [64]	training's binary_logloss: 0.256198	valid_1's binary_logloss: 0.267669
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [65]	training's binary_logloss: 0.255677	valid_1's binary_logloss: 0.267734
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [66]	training's binary_logloss: 0.255132	valid_1's binary_logloss: 0.267688
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [67]	training's binary_logloss: 0.254511	valid_1's binary_logloss: 0.267398
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [68]	training's binary_logloss: 0.254008	valid_1's binary_logloss: 0.267374
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [69]	training's binary_logloss: 0.253514	valid_1's binary_logloss: 0.267201
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [70]	training's binary_logloss: 0.252978	valid_1's binary_logloss: 0.267146
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [71]	training's binary_logloss: 0.252462	valid_1's binary_logloss: 0.266879
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [72]	training's binary_logloss: 0.2521	valid_1's binary_logloss: 0.266727
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 20
# [73]	training's binary_logloss: 0.251609	valid_1's binary_logloss: 0.266395
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [74]	training's binary_logloss: 0.25124	valid_1's binary_logloss: 0.26638
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [75]	training's binary_logloss: 0.250704	valid_1's binary_logloss: 0.266447
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [76]	training's binary_logloss: 0.250281	valid_1's binary_logloss: 0.266361
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [77]	training's binary_logloss: 0.249831	valid_1's binary_logloss: 0.266232
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [78]	training's binary_logloss: 0.24938	valid_1's binary_logloss: 0.265908
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [79]	training's binary_logloss: 0.248973	valid_1's binary_logloss: 0.265986
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [80]	training's binary_logloss: 0.248504	valid_1's binary_logloss: 0.265768
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [81]	training's binary_logloss: 0.248132	valid_1's binary_logloss: 0.265485
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [82]	training's binary_logloss: 0.247638	valid_1's binary_logloss: 0.26539
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [83]	training's binary_logloss: 0.247018	valid_1's binary_logloss: 0.265296
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 16
# [84]	training's binary_logloss: 0.246622	valid_1's binary_logloss: 0.265052
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [85]	training's binary_logloss: 0.246211	valid_1's binary_logloss: 0.264925
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [86]	training's binary_logloss: 0.24578	valid_1's binary_logloss: 0.264965
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [87]	training's binary_logloss: 0.245188	valid_1's binary_logloss: 0.264947
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [88]	training's binary_logloss: 0.244874	valid_1's binary_logloss: 0.264874
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [89]	training's binary_logloss: 0.24434	valid_1's binary_logloss: 0.264953
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [90]	training's binary_logloss: 0.243972	valid_1's binary_logloss: 0.264986
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [91]	training's binary_logloss: 0.243512	valid_1's binary_logloss: 0.264945
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [92]	training's binary_logloss: 0.243056	valid_1's binary_logloss: 0.264896
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [93]	training's binary_logloss: 0.242707	valid_1's binary_logloss: 0.264966
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [94]	training's binary_logloss: 0.242329	valid_1's binary_logloss: 0.265119
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [95]	training's binary_logloss: 0.241944	valid_1's binary_logloss: 0.265157
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [96]	training's binary_logloss: 0.241458	valid_1's binary_logloss: 0.265313
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [97]	training's binary_logloss: 0.240901	valid_1's binary_logloss: 0.265347
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [98]	training's binary_logloss: 0.240457	valid_1's binary_logloss: 0.265348
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [99]	training's binary_logloss: 0.240139	valid_1's binary_logloss: 0.26516
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [100]	training's binary_logloss: 0.239751	valid_1's binary_logloss: 0.265107
# Fold:  4
# [LightGBM] [Info] Number of positive: 5056, number of negative: 15783
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.905118
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.278498
# [LightGBM] [Debug] init for col-wise cost 0.001317 seconds, init for row-wise cost 0.003603 seconds
# [LightGBM] [Debug] col-wise cost 0.000469 seconds, row-wise cost 0.000377 seconds
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002163 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Debug] Using Sparse Multi-Val Bin
# [LightGBM] [Info] Total Bins 675
# [LightGBM] [Info] Number of data points in the train set: 20839, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.242622 -> initscore=-1.138358
# [LightGBM] [Info] Start training from score -1.138358
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [1]	training's binary_logloss: 0.509642	valid_1's binary_logloss: 0.509136
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [2]	training's binary_logloss: 0.476811	valid_1's binary_logloss: 0.478227
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [3]	training's binary_logloss: 0.450753	valid_1's binary_logloss: 0.454003
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# ...
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [98]	training's binary_logloss: 0.235239	valid_1's binary_logloss: 0.285067
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [99]	training's binary_logloss: 0.234829	valid_1's binary_logloss: 0.285178
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [100]	training's binary_logloss: 0.234447	valid_1's binary_logloss: 0.285279
# Fold:  5
# [LightGBM] [Info] Number of positive: 5004, number of negative: 15836
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.905686
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.278673
# [LightGBM] [Debug] init for col-wise cost 0.001646 seconds, init for row-wise cost 0.002603 seconds
# [LightGBM] [Debug] col-wise cost 0.000412 seconds, row-wise cost 0.000200 seconds
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002258 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Debug] Using Sparse Multi-Val Bin
# [LightGBM] [Info] Total Bins 671
# [LightGBM] [Info] Number of data points in the train set: 20840, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.240115 -> initscore=-1.152048
# [LightGBM] [Info] Start training from score -1.152048
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [1]	training's binary_logloss: 0.507215	valid_1's binary_logloss: 0.518814
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [2]	training's binary_logloss: 0.474511	valid_1's binary_logloss: 0.48718
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [3]	training's binary_logloss: 0.448768	valid_1's binary_logloss: 0.46198
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [4]	training's binary_logloss: 0.427457	valid_1's binary_logloss: 0.441194
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [5]	training's binary_logloss: 0.409876	valid_1's binary_logloss: 0.423865
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [6]	training's binary_logloss: 0.394799	valid_1's binary_logloss: 0.409543
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [7]	training's binary_logloss: 0.381852	valid_1's binary_logloss: 0.397591
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [8]	training's binary_logloss: 0.370345	valid_1's binary_logloss: 0.386686
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [9]	training's binary_logloss: 0.360683	valid_1's binary_logloss: 0.377326
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [10]	training's binary_logloss: 0.352155	valid_1's binary_logloss: 0.369534
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [11]	training's binary_logloss: 0.344557	valid_1's binary_logloss: 0.362544
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [12]	training's binary_logloss: 0.337969	valid_1's binary_logloss: 0.356317
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [13]	training's binary_logloss: 0.331574	valid_1's binary_logloss: 0.350031
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [14]	training's binary_logloss: 0.326168	valid_1's binary_logloss: 0.345052
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [15]	training's binary_logloss: 0.321112	valid_1's binary_logloss: 0.340404
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [16]	training's binary_logloss: 0.316901	valid_1's binary_logloss: 0.336464
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [17]	training's binary_logloss: 0.312706	valid_1's binary_logloss: 0.332939
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [18]	training's binary_logloss: 0.308989	valid_1's binary_logloss: 0.329648
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [19]	training's binary_logloss: 0.305628	valid_1's binary_logloss: 0.326424
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [20]	training's binary_logloss: 0.302369	valid_1's binary_logloss: 0.323516
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [21]	training's binary_logloss: 0.299366	valid_1's binary_logloss: 0.320663
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [22]	training's binary_logloss: 0.29673	valid_1's binary_logloss: 0.318352
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [23]	training's binary_logloss: 0.294181	valid_1's binary_logloss: 0.316012
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [24]	training's binary_logloss: 0.292	valid_1's binary_logloss: 0.314353
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [25]	training's binary_logloss: 0.290009	valid_1's binary_logloss: 0.312702
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [26]	training's binary_logloss: 0.288262	valid_1's binary_logloss: 0.311251
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [27]	training's binary_logloss: 0.286712	valid_1's binary_logloss: 0.309828
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [28]	training's binary_logloss: 0.284966	valid_1's binary_logloss: 0.308512
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [29]	training's binary_logloss: 0.282744	valid_1's binary_logloss: 0.306733
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [30]	training's binary_logloss: 0.281165	valid_1's binary_logloss: 0.305458
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 18
# [31]	training's binary_logloss: 0.279151	valid_1's binary_logloss: 0.30394
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [32]	training's binary_logloss: 0.277866	valid_1's binary_logloss: 0.303061
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 19
# [33]	training's binary_logloss: 0.275974	valid_1's binary_logloss: 0.301442
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [34]	training's binary_logloss: 0.274428	valid_1's binary_logloss: 0.300094
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [35]	training's binary_logloss: 0.273414	valid_1's binary_logloss: 0.299718
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [36]	training's binary_logloss: 0.272059	valid_1's binary_logloss: 0.298585
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [37]	training's binary_logloss: 0.270995	valid_1's binary_logloss: 0.297816
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [38]	training's binary_logloss: 0.269759	valid_1's binary_logloss: 0.297082
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [39]	training's binary_logloss: 0.268801	valid_1's binary_logloss: 0.296699
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 19
# [40]	training's binary_logloss: 0.267598	valid_1's binary_logloss: 0.296055
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [41]	training's binary_logloss: 0.266702	valid_1's binary_logloss: 0.295686
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [42]	training's binary_logloss: 0.265862	valid_1's binary_logloss: 0.295132
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [43]	training's binary_logloss: 0.265056	valid_1's binary_logloss: 0.294852
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 16
# [44]	training's binary_logloss: 0.264064	valid_1's binary_logloss: 0.294246
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [45]	training's binary_logloss: 0.26292	valid_1's binary_logloss: 0.293637
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 16
# [46]	training's binary_logloss: 0.262079	valid_1's binary_logloss: 0.293139
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 16
# [47]	training's binary_logloss: 0.261261	valid_1's binary_logloss: 0.292958
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 17
# [48]	training's binary_logloss: 0.260378	valid_1's binary_logloss: 0.292671
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 16
# [49]	training's binary_logloss: 0.259625	valid_1's binary_logloss: 0.292258
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [50]	training's binary_logloss: 0.258909	valid_1's binary_logloss: 0.291944
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [51]	training's binary_logloss: 0.258152	valid_1's binary_logloss: 0.29166
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [52]	training's binary_logloss: 0.257627	valid_1's binary_logloss: 0.291567
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [53]	training's binary_logloss: 0.257006	valid_1's binary_logloss: 0.291326
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 16
# [54]	training's binary_logloss: 0.256152	valid_1's binary_logloss: 0.290608
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [55]	training's binary_logloss: 0.25544	valid_1's binary_logloss: 0.290337
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [56]	training's binary_logloss: 0.254605	valid_1's binary_logloss: 0.289952
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [57]	training's binary_logloss: 0.253953	valid_1's binary_logloss: 0.289585
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [58]	training's binary_logloss: 0.253386	valid_1's binary_logloss: 0.289458
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [59]	training's binary_logloss: 0.252824	valid_1's binary_logloss: 0.289457
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [60]	training's binary_logloss: 0.25232	valid_1's binary_logloss: 0.289376
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [61]	training's binary_logloss: 0.251692	valid_1's binary_logloss: 0.289077
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [62]	training's binary_logloss: 0.251163	valid_1's binary_logloss: 0.289077
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [63]	training's binary_logloss: 0.250535	valid_1's binary_logloss: 0.288784
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [64]	training's binary_logloss: 0.249991	valid_1's binary_logloss: 0.288862
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [65]	training's binary_logloss: 0.249502	valid_1's binary_logloss: 0.288951
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [66]	training's binary_logloss: 0.248931	valid_1's binary_logloss: 0.288795
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [67]	training's binary_logloss: 0.248297	valid_1's binary_logloss: 0.288742
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [68]	training's binary_logloss: 0.247839	valid_1's binary_logloss: 0.288786
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [69]	training's binary_logloss: 0.247279	valid_1's binary_logloss: 0.288802
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [70]	training's binary_logloss: 0.246838	valid_1's binary_logloss: 0.288757
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [71]	training's binary_logloss: 0.246361	valid_1's binary_logloss: 0.288512
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [72]	training's binary_logloss: 0.245899	valid_1's binary_logloss: 0.288667
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [73]	training's binary_logloss: 0.245425	valid_1's binary_logloss: 0.288443
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [74]	training's binary_logloss: 0.244961	valid_1's binary_logloss: 0.28838
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [75]	training's binary_logloss: 0.2445	valid_1's binary_logloss: 0.28836
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [76]	training's binary_logloss: 0.244059	valid_1's binary_logloss: 0.288399
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [77]	training's binary_logloss: 0.243538	valid_1's binary_logloss: 0.288502
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [78]	training's binary_logloss: 0.243159	valid_1's binary_logloss: 0.288682
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [79]	training's binary_logloss: 0.242781	valid_1's binary_logloss: 0.288385
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [80]	training's binary_logloss: 0.242358	valid_1's binary_logloss: 0.288202
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [81]	training's binary_logloss: 0.241755	valid_1's binary_logloss: 0.288294
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [82]	training's binary_logloss: 0.241212	valid_1's binary_logloss: 0.288381
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [83]	training's binary_logloss: 0.240875	valid_1's binary_logloss: 0.288382
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [84]	training's binary_logloss: 0.24035	valid_1's binary_logloss: 0.288269
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [85]	training's binary_logloss: 0.23997	valid_1's binary_logloss: 0.288309
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [86]	training's binary_logloss: 0.239541	valid_1's binary_logloss: 0.288394
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [87]	training's binary_logloss: 0.239222	valid_1's binary_logloss: 0.288366
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 17
# [88]	training's binary_logloss: 0.238802	valid_1's binary_logloss: 0.288063
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [89]	training's binary_logloss: 0.238309	valid_1's binary_logloss: 0.288109
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [90]	training's binary_logloss: 0.237925	valid_1's binary_logloss: 0.288222
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [91]	training's binary_logloss: 0.237447	valid_1's binary_logloss: 0.28832
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 17
# [92]	training's binary_logloss: 0.237062	valid_1's binary_logloss: 0.288174
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [93]	training's binary_logloss: 0.236697	valid_1's binary_logloss: 0.288307
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [94]	training's binary_logloss: 0.236415	valid_1's binary_logloss: 0.288304
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [95]	training's binary_logloss: 0.235965	valid_1's binary_logloss: 0.288579
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [96]	training's binary_logloss: 0.235531	valid_1's binary_logloss: 0.288488
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [97]	training's binary_logloss: 0.235091	valid_1's binary_logloss: 0.288452
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [98]	training's binary_logloss: 0.234638	valid_1's binary_logloss: 0.28851
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [99]	training's binary_logloss: 0.234256	valid_1's binary_logloss: 0.288559
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [100]	training's binary_logloss: 0.233766	valid_1's binary_logloss: 0.288583

# %%
sample_submission['prediction'] = y_preds

for ix, row in sample_submission.iterrows():
    if row['prediction'] > 0.5:
        sample_submission.loc[ix, 'prediction'] = 1
    else:
        sample_submission.loc[ix, 'prediction'] = 0

sample_submission = sample_submission.astype({"prediction": int})
sample_submission.to_csv('submission_3.csv', index=False)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
col = 'prediction'
value_counts = sample_submission[col].value_counts()
sns.countplot(x=col, data=sample_submission, palette="Set2", edgecolor='black', order = value_counts.index)

for i, v in value_counts.reset_index().iterrows():
    ax.text(i-0.05, v[col]+150 , v[col])

# %%
ll
# Out:
# total 7416
# -rw-rw-r--@ 1 pym  staff    44488 Oct 13 11:00 sample_submission.csv
# -rw-r--r--  1 pym  staff    44488 Oct 27 16:35 submission.csv
# -rw-r--r--  1 pym  staff    44488 Oct 27 16:36 submission_1.csv
# -rw-rw-r--@ 1 pym  staff   699385 Oct 13 11:00 test.csv
# -rw-rw-r--@ 1 pym  staff  2958474 Oct 13 11:00 train.csv
